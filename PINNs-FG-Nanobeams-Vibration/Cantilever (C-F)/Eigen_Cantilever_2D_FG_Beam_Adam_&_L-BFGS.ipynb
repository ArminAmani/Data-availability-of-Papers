# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <h1 align="center"><font size = 14>Unsupervised PINNs for free-vibration eigenanalysis of 2-D FG Euler–Bernoulli nanobeams under NSGT (C-F)</font></h1>
# <h3 align="center">Armin Amani</h3>
# <h4 align="center">E-mail address: arminamani8251@gmail.com<h4>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 📤 Import Libraries

# %%
from __future__ import annotations

import argparse
import copy
import gc
import json
import logging
import math
import random
import warnings
from dataclasses import asdict, dataclass
from pathlib import Path
from typing import Dict, Optional, Tuple

import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

try:
    from scipy.integrate import cumulative_trapezoid, solve_bvp
    SCIPY_AVAILABLE = True
except Exception:
    cumulative_trapezoid = None
    solve_bvp = None
    SCIPY_AVAILABLE = False

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Configuration Setting and Determine Parameters

# %%
torch.set_default_dtype(torch.float64)

LOGGER = logging.getLogger("pinn_2dfg_eb_nsgt_cf")
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)


# Configuration

@dataclass
class Config:
    # Material: ceramic = Al2O3, metal = steel
    E_c: float = 390.0e9
    rho_c: float = 3960.0
    E_m: float = 210.0e9
    rho_m: float = 7800.0

    # 2D-FG exponents
    k: float = 1.0
    beta: float = 1.0

    # Geometry
    h: float = 17.6e-6
    b_over_h: float = 2.0
    L_over_h: float = 30.0

    # Dimensionless NSGT length parameters
    tau: float = 0.05
    zeta: float = 0.05

    # PINN collocation and quadrature
    n_colloc: int = 128
    n_quad: int = 128
    n_test: int = 401

    x_min: float = 0.0
    x_max: float = 1.0

    """
    Network: X -> Phi(X)
    
    Biases are required because the C-F hard clamped-end parametrization
    must not introduce unintended additional endpoint restrictions.
    """
    hidden_1: int = 128
    hidden_2: int = 64
    hidden_3: int = 32

    use_bias: bool = True

    # Hybrid optimization
    # Phase I  : Adam for global exploration / initial convergence.
    # Phase II : Full-batch L-BFGS for deterministic quasi-Newton refinement.

    # Phase I: Adam
    adam_epochs: int = 20_000

    lr_nn: float = 2.0e-3
    lr_lambda: float = 1.0e-3

    lambda_init: float = 100.0

    # Absolute Adam learning-rate milestones.
    lr_milestones: Tuple[int, ...] = (
        3_000,
        4_250,
        15_000,
    )

    lr_gamma: float = 0.20

    # Phase II: L-BFGS
    lbfgs_max_iter: int = 10_000
    lbfgs_block_iter: int = 100

    lbfgs_lr: float = 1.0
    lbfgs_history_size: int = 100

    lbfgs_tolerance_grad: float = 1.0e-9
    lbfgs_tolerance_change: float = 1.0e-12

    lbfgs_line_search_fn: str = "strong_wolfe"

    # Loss weights
    alpha_de: float = 1.0
    alpha_bc: float = 10.0

    # The eigenfunction is differentiably mass-normalized inside compute_loss.
    # Therefore no separate normalization penalty is required.
    alpha_norm: float = 0.0

    l2_coeff: float = 1.0e-6
    apply_l2: bool = False

    # Optional Adam gradient clipping.
    grad_clip_norm: Optional[float] = None

    # Reproducibility
    seed: Optional[int] = 42
    deterministic_torch: bool = True

    # Logging / output
    log_every: int = 50
    plot_every: int = 500
    save_epoch_plots: bool = True

    output_dir: str = (
        "results_2dfg_eb_nsgt_cf_"
        "adam20k_lbfgs10k_alphaBC10_seed42"
    )

    device: str = "auto"

    """
    Independent SciPy BVP reference
    
    The BVP solution is used only for independent post-training validation
    and optional visualization. It must not enter:
    
      - the PINN objective,
      - Adam updates,
      - L-BFGS updates,
      - optimizer switching,
      - checkpoint selection,
      - stopping criteria,
      - learning-rate scheduling.
    """
    run_reference_bvp: bool = True

    reference_lambda_guess: float = 10.0
    reference_tol: float = 1.0e-7
    reference_max_nodes: int = 20_000

    # Derived geometry / reference quantities
    @property
    def b(self) -> float:
        return self.b_over_h * self.h

    @property
    def L(self) -> float:
        return self.L_over_h * self.h

    @property
    def area(self) -> float:
        return self.b * self.h

    @property
    def I_g(self) -> float:
        return self.b * self.h**3 / 12.0

    @property
    def D0(self) -> float:
        return self.E_c * self.I_g

    @property
    def m0(self) -> float:
        return self.rho_c * self.area

    @property
    def mu(self) -> float:
        return self.tau * self.L

    @property
    def ell(self) -> float:
        return self.zeta * self.L

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Validation & seeds for reproducibility

# %%
# Validation, reproducibility, and device

def validate_config(cfg: Config) -> None:
    # Material and geometry
    if cfg.E_c <= 0 or cfg.E_m <= 0:
        raise ValueError("Elastic moduli must be positive.")

    if cfg.rho_c <= 0 or cfg.rho_m <= 0:
        raise ValueError("Densities must be positive.")

    if cfg.h <= 0 or cfg.b_over_h <= 0 or cfg.L_over_h <= 0:
        raise ValueError(
            "Geometry parameters h, b/h and L/h must be positive."
        )

    if cfg.k < 0 or cfg.beta < 0:
        raise ValueError(
            "The project power-law exponents require k >= 0 and beta >= 0."
        )

    # NSGT parameters
    if cfg.tau < 0:
        raise ValueError("tau must be nonnegative.")

    if cfg.zeta <= 0:
        raise ValueError(
            "zeta must be strictly positive for the sixth-order C-F model with "
            "six boundary conditions. Treat zeta=0 with a separate reduced-order model."
        )

    # Collocation / quadrature / test grids
    if cfg.n_colloc < 16:
        raise ValueError(
            "Use at least 16 interior collocation points."
        )

    if cfg.n_quad < 16:
        raise ValueError(
            "Use at least 16 quadrature points."
        )

    if cfg.n_test < 3:
        raise ValueError(
            "n_test must be at least 3."
        )

    if cfg.x_max <= cfg.x_min:
        raise ValueError(
            "x_max must be strictly greater than x_min."
        )

    # Network
    if cfg.hidden_1 < 1 or cfg.hidden_2 < 1 or cfg.hidden_3 < 1:
        raise ValueError(
            "All hidden-layer widths must be positive."
        )

    # Eigenvalue initialization
    if cfg.lambda_init <= 0:
        raise ValueError(
            "lambda_init must be positive."
        )

    # Phase I: Adam validation
    if cfg.adam_epochs < 1:
        raise ValueError(
            "adam_epochs must be positive."
        )

    if cfg.lr_nn <= 0:
        raise ValueError(
            "lr_nn must be positive."
        )

    if cfg.lr_lambda <= 0:
        raise ValueError(
            "lr_lambda must be positive."
        )

    if not (0.0 < cfg.lr_gamma <= 1.0):
        raise ValueError(
            "lr_gamma must satisfy 0 < lr_gamma <= 1."
        )

    if len(cfg.lr_milestones) == 0:
        raise ValueError(
            "At least one Adam LR milestone is required."
        )

    if tuple(sorted(set(cfg.lr_milestones))) != cfg.lr_milestones:
        raise ValueError(
            "lr_milestones must be strictly increasing and unique."
        )

    if any(
        milestone <= 0 or milestone >= cfg.adam_epochs
        for milestone in cfg.lr_milestones
    ):
        raise ValueError(
            "Each Adam LR milestone must satisfy "
            "0 < milestone < adam_epochs."
        )

    # Phase II: L-BFGS validation
    if cfg.lbfgs_max_iter < 1:
        raise ValueError(
            "lbfgs_max_iter must be positive."
        )

    if cfg.lbfgs_block_iter < 1:
        raise ValueError(
            "lbfgs_block_iter must be positive."
        )

    if cfg.lbfgs_block_iter > cfg.lbfgs_max_iter:
        raise ValueError(
            "lbfgs_block_iter must not exceed lbfgs_max_iter."
        )

    if cfg.lbfgs_lr <= 0:
        raise ValueError(
            "lbfgs_lr must be positive."
        )

    if cfg.lbfgs_history_size < 1:
        raise ValueError(
            "lbfgs_history_size must be positive."
        )

    if cfg.lbfgs_tolerance_grad < 0:
        raise ValueError(
            "lbfgs_tolerance_grad must be nonnegative."
        )

    if cfg.lbfgs_tolerance_change < 0:
        raise ValueError(
            "lbfgs_tolerance_change must be nonnegative."
        )

    if cfg.lbfgs_line_search_fn not in ("strong_wolfe",):
        raise ValueError(
            "For the present implementation, "
            "lbfgs_line_search_fn must be 'strong_wolfe'."
        )

    # Loss configuration
    if cfg.alpha_de < 0:
        raise ValueError(
            "alpha_de must be nonnegative."
        )

    if cfg.alpha_bc < 0:
        raise ValueError(
            "alpha_bc must be nonnegative."
        )

    if cfg.alpha_norm < 0:
        raise ValueError(
            "alpha_norm must be nonnegative."
        )

    if cfg.l2_coeff < 0:
        raise ValueError(
            "l2_coeff must be nonnegative."
        )

    if (
        cfg.grad_clip_norm is not None
        and cfg.grad_clip_norm <= 0
    ):
        raise ValueError(
            "grad_clip_norm must be positive when enabled."
        )

    # Logging / plotting
    if cfg.log_every < 1:
        raise ValueError(
            "log_every must be positive."
        )

    if cfg.plot_every < 1:
        raise ValueError(
            "plot_every must be positive."
        )

    # Independent BVP reference
    if cfg.reference_lambda_guess <= 0:
        raise ValueError(
            "reference_lambda_guess must be positive."
        )

    if cfg.reference_tol <= 0:
        raise ValueError(
            "reference_tol must be positive."
        )

    if cfg.reference_max_nodes < 10:
        raise ValueError(
            "reference_max_nodes must be at least 10."
        )

    # Regularity caveat
    is_integer_k = abs(
        cfg.k - round(cfg.k)
    ) < 1.0e-12

    if (not is_integer_k) and cfg.k < 3.0:
        warnings.warn(
            "Fractional k < 3 makes some coefficient derivatives singular "
            "at X=0 in the expanded strong form. PINN interior collocation "
            "is still allowed, but the endpoint BVP reference will be skipped.",
            RuntimeWarning,
        )


def set_seed(
    seed: Optional[int],
    deterministic: bool = False,
) -> None:
    if seed is None:
        return

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    if deterministic:
        torch.use_deterministic_algorithms(
            True,
            warn_only=True,
        )

        if torch.cuda.is_available():
            torch.backends.cudnn.benchmark = False
            torch.backends.cudnn.deterministic = True


def resolve_device(
    device_arg: str,
) -> torch.device:
    if device_arg == "auto":
        return torch.device(
            "cuda"
            if torch.cuda.is_available()
            else "cpu"
        )

    return torch.device(
        device_arg
    )

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 2D-FG section resultants and dimensionless coefficient functions

# %%
# 2D-FG section resultants and dimensionless coefficient functions

def _section_constants(cfg: Config) -> Tuple[float, float, float]:
    """Thickness power-law integrals used by A11, B11 and D11."""
    beta = cfg.beta
    cA = 1.0 / (beta + 1.0)
    cB = beta / (2.0 * (beta + 1.0) * (beta + 2.0))
    cD = (beta**2 + beta + 2.0) / (
        4.0 * (beta + 1.0) * (beta + 2.0) * (beta + 3.0)
    )
    return cA, cB, cD


def section_resultants_numpy(X: np.ndarray, cfg: Config) -> Dict[str, np.ndarray]:
    """Closed-form A11, B11, D11, D*, I0, I1, I2 for the 2D-FG law."""
    X = np.asarray(X, dtype=np.float64)
    q = np.power(X, cfg.k)
    cA, cB, cD = _section_constants(cfg)

    dE = cfg.E_m - cfg.E_c
    drho = cfg.rho_m - cfg.rho_c

    A11 = cfg.b * cfg.h * (cfg.E_c + dE * cA * q)
    B11 = cfg.b * cfg.h**2 * (dE * cB * q)
    D11 = cfg.b * cfg.h**3 * (cfg.E_c / 12.0 + dE * cD * q)
    Dstar = D11 - B11**2 / A11

    I0 = cfg.b * cfg.h * (cfg.rho_c + drho * cA * q)
    I1 = cfg.b * cfg.h**2 * (drho * cB * q)
    I2 = cfg.b * cfg.h**3 * (cfg.rho_c / 12.0 + drho * cD * q)

    zE = B11 / A11
    zrho = I1 / I0

    d = Dstar / cfg.D0
    r = I0 / cfg.m0

    return {
        "A11": A11,
        "B11": B11,
        "D11": D11,
        "Dstar": Dstar,
        "I0": I0,
        "I1": I1,
        "I2": I2,
        "zE": zE,
        "zrho": zrho,
        "d": d,
        "r": r,
    }


def dimensionless_coefficients_torch(
    X: torch.Tensor,
    cfg: Config,
) -> Tuple[torch.Tensor, torch.Tensor]:
    """
    Return d(X)=D*/D0 and r(X)=I0/m0 in a scale-safe dimensionless form.

    The formula is algebraically identical to the physical resultants above,
    but avoids carrying E~1e11 and h~1e-5 through high-order AD.
    """
    q = X.pow(cfg.k)
    cA, cB, cD = _section_constants(cfg)

    eta_E = (cfg.E_m - cfg.E_c) / cfg.E_c
    eta_rho = (cfg.rho_m - cfg.rho_c) / cfg.rho_c

    # A11/(b h Ec), B11/(b h^2 Ec), D11/(b h^3 Ec)
    Abar = 1.0 + eta_E * cA * q
    Bbar = eta_E * cB * q
    Dbar = 1.0 / 12.0 + eta_E * cD * q

    # D0 = Ec b h^3 / 12
    d = 12.0 * (Dbar - Bbar.square() / Abar)
    r = 1.0 + eta_rho * cA * q
    return d, r


def verify_closed_form_section_resultants(cfg: Config, n_z: int = 120) -> None:
    """Numerically integrate through thickness and verify all closed forms."""
    xi, w = np.polynomial.legendre.leggauss(n_z)
    xi = 0.5 * (xi + 1.0)
    w = 0.5 * w
    z = cfg.h * (xi - 0.5)

    Xs = np.array([0.0, 0.2, 0.5, 0.8, 1.0], dtype=np.float64)
    exact = section_resultants_numpy(Xs, cfg)

    num = {key: [] for key in ["A11", "B11", "D11", "I0", "I1", "I2"]}
    for X in Xs:
        qx = X**cfg.k
        E = cfg.E_c + (cfg.E_m - cfg.E_c) * qx * xi**cfg.beta
        rho = cfg.rho_c + (cfg.rho_m - cfg.rho_c) * qx * xi**cfg.beta
        dA_weight = cfg.b * cfg.h * w

        num["A11"].append(np.sum(E * dA_weight))
        num["B11"].append(np.sum(z * E * dA_weight))
        num["D11"].append(np.sum(z**2 * E * dA_weight))
        num["I0"].append(np.sum(rho * dA_weight))
        num["I1"].append(np.sum(z * rho * dA_weight))
        num["I2"].append(np.sum(z**2 * rho * dA_weight))

    max_rel = 0.0
    for key in num:
        a = np.asarray(num[key])
        b = np.asarray(exact[key])
        # Use a global characteristic scale for each resultant.  B11 and I1
        # are exactly zero at X=0 for k>0, so pointwise relative error would
        # incorrectly amplify harmless Gauss-quadrature cancellation noise.
        scale = max(float(np.max(np.abs(b))), 1.0e-300)
        rel = float(np.max(np.abs(a - b)) / scale)
        max_rel = max(max_rel, rel)

    LOGGER.info("Closed-form section-resultant check: max relative error = %.3e", max_rel)
    if max_rel > 1.0e-9:
        raise RuntimeError("Section-resultant closed-form verification failed.")


def validate_coefficient_profiles(cfg: Config) -> None:
    X = np.linspace(0.0, 1.0, 1001)
    sec = section_resultants_numpy(X, cfg)
    if not np.all(np.isfinite(sec["d"])) or not np.all(np.isfinite(sec["r"])):
        raise ValueError("Non-finite d(X) or r(X) detected.")
    if np.min(sec["d"]) <= 0:
        raise ValueError("Condensed bending stiffness D*(X) is non-positive.")
    if np.min(sec["r"]) <= 0:
        raise ValueError("Mass coefficient r(X) is non-positive.")

    LOGGER.info(
        "Coefficient ranges: d(X)=[%.6g, %.6g], r(X)=[%.6g, %.6g]",
        np.min(sec["d"]), np.max(sec["d"]), np.min(sec["r"]), np.max(sec["r"]),
    )
    LOGGER.info(
        "Max |z_E|/h = %.6g, max |z_rho|/h = %.6g; I1^rho is %s in general.",
        np.max(np.abs(sec["zE"])) / cfg.h,
        np.max(np.abs(sec["zrho"])) / cfg.h,
        "nonzero" if np.max(np.abs(sec["I1"])) > 1.0e-30 else "zero",
    )

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 NeuralNetwork

# %%
class NeuralNetwork(nn.Module):
    """X -> Phi(X), 1 -> 128 -> 64 -> 32 -> 1 by default, SiLU/Swish."""

    def __init__(self, cfg: Config):
        super().__init__()
        self.fc1 = nn.Linear(1, cfg.hidden_1, bias=cfg.use_bias)
        self.fc2 = nn.Linear(cfg.hidden_1, cfg.hidden_2, bias=cfg.use_bias)
        self.fc3 = nn.Linear(cfg.hidden_2, cfg.hidden_3, bias=cfg.use_bias)
        self.out = nn.Linear(cfg.hidden_3, 1, bias=cfg.use_bias)
        self.act = nn.SiLU()
        self._glorot_uniform_init()

    def _glorot_uniform_init(self) -> None:
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                if module.bias is not None:
                    nn.init.zeros_(module.bias)

    def forward(self, X: torch.Tensor) -> torch.Tensor:
        X = self.act(self.fc1(X))
        X = self.act(self.fc2(X))
        X = self.act(self.fc3(X))
        return self.out(X)

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 EigenPINN

# %%
class EigenPINN(nn.Module):
    """
    Hard-constrained eigenvalue PINN for the current
    C-F (cantilever) fixed-curvature formulation.

    The raw eigenfunction is represented as

        Phi_raw(X) = B(X) * N_theta(X),

    with

        B(X) = xi^3,

        xi = (X - x_min) / (x_max - x_min),

    which exactly satisfies the clamped-end conditions

        Phi_raw(x_min)   = 0,
        Phi_raw'(x_min)  = 0,
        Phi_raw''(x_min) = 0.

    No displacement, slope, or curvature condition is imposed
    structurally at the free end X = x_max. The required free-end
    conditions are enforced separately in the boundary-condition loss.

    The positive eigenvalue is parameterized logarithmically as

        lambda = exp(lambda_raw),

    which gives a scale-appropriate multiplicative parametrization.
    """

    def __init__(self, cfg: Config):
        super().__init__()

        if not cfg.use_bias:
            raise ValueError(
                "The hard C-F parametrization requires use_bias=True. "
                "For the present domain starting at X=0, a bias-free SiLU "
                "network would unintentionally impose an additional "
                "higher-order restriction at the clamped end."
            )

        if cfg.lambda_init <= 0.0:
            raise ValueError(
                "lambda_init must be strictly positive."
            )

        self.nn_phi = NeuralNetwork(cfg)

        self.x_min = float(cfg.x_min)
        self.x_max = float(cfg.x_max)

        if self.x_max <= self.x_min:
            raise ValueError(
                "Require x_max > x_min."
            )

        # Logarithmic positive eigenvalue parametrization.
        self.lambda_raw = nn.Parameter(
            torch.tensor(
                math.log(cfg.lambda_init),
                dtype=torch.float64,
            )
        )

    @property
    def lambda_(self) -> torch.Tensor:
        return torch.exp(self.lambda_raw)

    def cf_clamped_boundary_factor(
        self,
        X: torch.Tensor,
    ) -> torch.Tensor:
        """
        Hard clamped-end envelope for the C-F cantilever model.

        B = B' = B'' = 0 at X = x_min.

        No corresponding hard restriction is imposed at X = x_max.
        """
        xi = (
            (X - self.x_min)
            / (self.x_max - self.x_min)
        )

        return xi.pow(3)

    def forward(
        self,
        X: torch.Tensor,
    ) -> torch.Tensor:
        latent_mode = self.nn_phi(X)

        return (
            self.cf_clamped_boundary_factor(X)
            * latent_mode
        )

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Automatic differentiation and operators

# %%
# Automatic differentiation and operators

def derivative(y: torch.Tensor, x: torch.Tensor) -> torch.Tensor:
    return torch.autograd.grad(
        outputs=y,
        inputs=x,
        grad_outputs=torch.ones_like(y),
        create_graph=True,
        retain_graph=True,
        only_inputs=True,
    )[0]


def nth_derivative(y: torch.Tensor, x: torch.Tensor, order: int) -> torch.Tensor:
    out = y
    for _ in range(order):
        out = derivative(out, x)
    return out


def phi_derivatives(
    model: EigenPINN,
    X: torch.Tensor,
    max_order: int,
) -> Tuple[torch.Tensor, ...]:
    if not X.requires_grad:
        raise ValueError("X must have requires_grad=True for spatial differentiation.")
    values = [model(X)]
    for _ in range(max_order):
        values.append(derivative(values[-1], X))
    return tuple(values)


def compact_governing_residual(
    model: EigenPINN,
    X: torch.Tensor,
    cfg: Config,
) -> Tuple[torch.Tensor, Dict[str, torch.Tensor]]:
    """
    Compact operator implementation of
      R = (d Phi'')'' - zeta^2 (d Phi''')'''
          - lambda [r Phi - tau^2 (r Phi)''].

    This form is preferred for training because it mirrors the derived
    divergence/operator structure and avoids manually coding d', d'', d'''.
    """
    if not X.requires_grad:
        raise ValueError("X must require gradients.")

    phi = model(X)
    phi1 = derivative(phi, X)
    phi2 = derivative(phi1, X)
    phi3 = derivative(phi2, X)

    d, r = dimensionless_coefficients_torch(X, cfg)

    bending_flux = d * phi2
    bending = derivative(derivative(bending_flux, X), X)

    gradient_flux = d * phi3
    gradient = derivative(derivative(derivative(gradient_flux, X), X), X)

    mass_product = r * phi
    mass_second = derivative(derivative(mass_product, X), X)
    mass_operator = r * phi - (cfg.tau**2) * mass_second

    residual = bending - (cfg.zeta**2) * gradient - model.lambda_ * mass_operator

    return residual, {
        "phi": phi,
        "phi1": phi1,
        "phi2": phi2,
        "phi3": phi3,
        "d": d,
        "r": r,
        "bending_operator": bending,
        "gradient_operator": gradient,
        "mass_operator": mass_operator,
    }


def verify_compact_vs_expanded_operator(cfg: Config, device: torch.device) -> None:
    """Algebraic/AD self-check of compact and expanded governing operators."""
    X = torch.linspace(0.08, 0.92, 31, device=device).reshape(-1, 1)
    X.requires_grad_(True)

    # Smooth nontrivial test function independent of the PINN.
    phi = X**3 * (1.0 - X)**3 * torch.exp(0.3 * X)
    phi1 = derivative(phi, X)
    phi2 = derivative(phi1, X)
    phi3 = derivative(phi2, X)
    phi4 = derivative(phi3, X)
    phi5 = derivative(phi4, X)
    phi6 = derivative(phi5, X)

    d, r = dimensionless_coefficients_torch(X, cfg)
    d1 = derivative(d, X)
    d2 = derivative(d1, X)
    d3 = derivative(d2, X)
    r1 = derivative(r, X)
    r2 = derivative(r1, X)

    lam = torch.tensor(123.456, dtype=X.dtype, device=device)

    compact = (
        derivative(derivative(d * phi2, X), X)
        - cfg.zeta**2 * derivative(derivative(derivative(d * phi3, X), X), X)
        - lam * (r * phi - cfg.tau**2 * derivative(derivative(r * phi, X), X))
    )

    expanded = (
        d * phi4 + 2.0 * d1 * phi3 + d2 * phi2
        - cfg.zeta**2
        * (d * phi6 + 3.0 * d1 * phi5 + 3.0 * d2 * phi4 + d3 * phi3)
        - lam
        * (
            r * phi
            - cfg.tau**2 * (r * phi2 + 2.0 * r1 * phi1 + r2 * phi)
        )
    )

    abs_err = torch.max(torch.abs(compact - expanded)).item()
    scale = max(torch.max(torch.abs(expanded)).item(), 1.0)
    rel_err = abs_err / scale
    LOGGER.info(
        "Compact-vs-expanded operator check: max abs=%.3e, relative=%.3e",
        abs_err,
        rel_err,
    )
    if rel_err > 5.0e-9:
        raise RuntimeError("Compact and expanded operator forms are inconsistent.")

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Quadrature, boundary conditions, loss

# %%
# Quadrature, boundary conditions, regularization, and PINN loss

def gauss_legendre_tensors(
    n: int,
    device: torch.device,
    x_min: float = 0.0,
    x_max: float = 1.0,
) -> Tuple[torch.Tensor, torch.Tensor]:
    """
    Return Gauss-Legendre quadrature nodes and weights over [x_min, x_max].
    """
    if n < 1:
        raise ValueError("Number of quadrature points must be positive.")

    if x_max <= x_min:
        raise ValueError("Quadrature interval must satisfy x_max > x_min.")

    xi, wi = np.polynomial.legendre.leggauss(n)

    # Affine mapping from [-1, 1] to [x_min, x_max].
    X = (
        0.5 * (x_max - x_min) * xi
        + 0.5 * (x_max + x_min)
    )

    W = (
        0.5 * (x_max - x_min) * wi
    )

    X_tensor = torch.tensor(
        X,
        dtype=torch.float64,
        device=device,
    ).reshape(-1, 1)

    W_tensor = torch.tensor(
        W,
        dtype=torch.float64,
        device=device,
    ).reshape(-1, 1)

    return X_tensor, W_tensor


def endpoint_bc_residuals(
    model: EigenPINN,
    cfg: Config,
    device: torch.device,
) -> Dict[str, torch.Tensor]:
    """
    Working Li-type C-F fixed-curvature boundary conditions.

    Clamped end, X = x_min:

        Phi   = 0,
        Phi'  = 0,
        Phi'' = 0,

    which are imposed exactly by the hard trial-function parametrization.

    Free end, X = x_max:

        Phi''       = 0,
        Mbar        = 0,
        d(Mbar)/dX  = 0,

    where the dimensionless physical bending moment for the present
    reduced flexural 2D-FG EB-NSGT eigenproblem is

        Mbar
        = -d Phi''
          + zeta^2 (d Phi''')'
          - tau^2 lambda r Phi.

    The free-end displacement Phi and slope Phi' remain unconstrained.
    """

    # Clamped end
    X0 = torch.tensor(
        [[cfg.x_min]],
        dtype=torch.float64,
        device=device,
        requires_grad=True,
    )

    phi_0, dphi_0, ddphi_0 = phi_derivatives(
        model,
        X0,
        2,
    )

    # Free end
    X1 = torch.tensor(
        [[cfg.x_max]],
        dtype=torch.float64,
        device=device,
        requires_grad=True,
    )

    phi_1, dphi_1, ddphi_1, dddphi_1 = phi_derivatives(
        model,
        X1,
        3,
    )

    d_1, r_1 = dimensionless_coefficients_torch(
        X1,
        cfg,
    )

    """
    Strain-gradient part:
    
        (d Phi''')'
    
    This compact AD form automatically includes
    
        d' Phi''' + d Phi''''.
    """
    moment_core_1 = derivative(
        d_1 * dddphi_1,
        X1,
    )

    """
    Full dimensionless physical bending moment at the free end:
    
        Mbar = -d Phi''
               + zeta^2 (d Phi''')'
               - tau^2 lambda r Phi.
    """
    moment_1 = (
        -d_1 * ddphi_1
        + (cfg.zeta**2) * moment_core_1
        - (cfg.tau**2) * model.lambda_ * r_1 * phi_1
    )

    """
    Free-end shear/resultant condition:
    
        d(Mbar)/dX = 0.
    
    Differentiating the full physical moment is important because the
    tau-dependent inertia contribution is generally nonzero at a free end.
    """
    shear_1 = derivative(
        moment_1,
        X1,
    )

    return {
        # Hard clamped-end diagnostics
        "phi_0": phi_0[0, 0],
        "dphi_0": dphi_0[0, 0],
        "ddphi_0": ddphi_0[0, 0],

        # Free-end kinematic diagnostics
        "phi_1": phi_1[0, 0],
        "dphi_1": dphi_1[0, 0],

        # Active free-end boundary residuals
        "ddphi_1": ddphi_1[0, 0],
        "moment_1": moment_1[0, 0],
        "shear_1": shear_1[0, 0],
    }


def explicit_l2_penalty(
    model: EigenPINN,
) -> torch.Tensor:
    """
    Explicit L2 penalty on neural-network parameters only.

    The trainable eigenvalue lambda is intentionally excluded.
    """

    penalty = model.lambda_raw.new_zeros(())

    for parameter in model.nn_phi.parameters():
        penalty = (
            penalty
            + torch.sum(parameter.square())
        )

    return penalty


def compute_loss(
    model: EigenPINN,
    X_colloc_base: torch.Tensor,
    X_quad: torch.Tensor,
    W_quad: torch.Tensor,
    cfg: Config,
    device: torch.device,
) -> Tuple[torch.Tensor, Dict[str, torch.Tensor]]:
    """
    Physics-informed loss for the hard/hybrid C-F eigenvalue PINN.

    The clamped-end conditions

        Phi = Phi' = Phi'' = 0

    are satisfied exactly by the trial-function parametrization.

    The three free-end conditions

        Phi'' = 0,
        Mbar = 0,
        d(Mbar)/dX = 0

    are imposed through the active boundary-condition loss.

    The raw eigenfunction is differentiably mass-normalized inside the
    governing-equation and boundary-condition residuals:

        Phi_hat = Phi_raw / sqrt(int r Phi_raw^2 dX).

    This removes the trivial-amplitude solution without using any
    reference eigenvalue or eigenfunction.
    """

    # Fresh interior collocation leaf
    X = (
        X_colloc_base
        .detach()
        .clone()
        .requires_grad_(True)
    )

    # Raw governing-equation residual
    residual_raw, fields = compact_governing_residual(
        model=model,
        X=X,
        cfg=cfg,
    )

    # Raw mass norm
    # I_raw = int r(X) Phi_raw(X)^2 dX
    phi_q_raw = model(X_quad)

    _, r_q = dimensionless_coefficients_torch(
        X_quad,
        cfg,
    )

    raw_mass_norm_integral = torch.sum(
        W_quad
        * r_q
        * phi_q_raw.square()
    )

    raw_norm_value = float(
        raw_mass_norm_integral
        .detach()
        .cpu()
    )

    if (
        not math.isfinite(raw_norm_value)
        or raw_norm_value <= 1.0e-24
    ):
        raise FloatingPointError(
            "Raw eigenfunction mass norm became numerically degenerate. "
            "Inspect network initialization and optimization."
        )

    # IMPORTANT:
    # Do not detach this factor. Its gradient with respect to the network
    # parameters is required for differentiable normalization.
    mode_scale = torch.rsqrt(
        raw_mass_norm_integral
    )

    # Governing residual of the mass-normalized mode
    residual = (
        mode_scale
        * residual_raw
    )

    # Scale-aware PDE residual diagnostics
    bending_term = (
        mode_scale
        * fields["bending_operator"]
    )

    gradient_term = (
        mode_scale
        * (cfg.zeta**2)
        * fields["gradient_operator"]
    )

    mass_term = (
        mode_scale
        * model.lambda_
        * fields["mass_operator"]
    )

    loss_de_raw = torch.mean(
        residual.square()
    )

    residual_rms = torch.sqrt(
        loss_de_raw
    )

    operator_scale_rms = (
        torch.sqrt(torch.mean(bending_term.square()))
        + torch.sqrt(torch.mean(gradient_term.square()))
        + torch.sqrt(torch.mean(mass_term.square()))
    )

    relative_residual_rms = (
        residual_rms
        / (
            operator_scale_rms
            + torch.finfo(residual.dtype).eps
        )
    )

    # C-F boundary conditions
    bc_raw = endpoint_bc_residuals(
        model=model,
        cfg=cfg,
        device=device,
    )

    # All boundary operators are linear and homogeneous in Phi, so the
    # corresponding residuals for the mass-normalized mode are obtained
    # by multiplication with the same spatially constant mode_scale.
    bc = {
        key: mode_scale * value
        for key, value in bc_raw.items()
    }

    # Only the three free-end conditions participate in the active BC loss.
    free_bc_vector = torch.stack(
        (
            bc["ddphi_1"],
            bc["moment_1"],
            bc["shear_1"],
        )
    )

    loss_bc_raw = torch.mean(
        free_bc_vector.square()
    )

    # Exact differentiable mass normalization
    # int r Phi_hat^2 dX = 1
    norm_integral = (
        raw_mass_norm_integral
        * mode_scale.square()
    )

    norm_error = (
        norm_integral
        - 1.0
    )

    norm_physical_raw = (
        norm_error.square()
    )

    # Retained only for API/history compatibility.
    # With exact differentiable normalization this should be ~ machine zero.
    loss_norm_raw = (
        norm_physical_raw
    )

    # Weighted losses
    loss_de = (
        cfg.alpha_de
        * loss_de_raw
    )

    loss_bc = (
        cfg.alpha_bc
        * loss_bc_raw
    )

    loss_norm = (
        cfg.alpha_norm
        * loss_norm_raw
    )

    # Optional L2 regularization
    # Recommended OFF for the present normalized eigenfunction formulation.
    if (
        cfg.apply_l2
        and cfg.l2_coeff > 0.0
    ):
        loss_l2 = (
            cfg.l2_coeff
            * explicit_l2_penalty(model)
        )
    else:
        loss_l2 = (
            model.lambda_raw
            .new_zeros(())
        )

    # Total objective
    total = (
        loss_de
        + loss_bc
        + loss_norm
        + loss_l2
    )

    # Diagnostics
    comp: Dict[str, torch.Tensor] = {
        "total": total,

        "de": loss_de,
        "de_raw": loss_de_raw,

        "bc": loss_bc,
        "bc_raw": loss_bc_raw,

        "norm": loss_norm,
        "norm_raw": loss_norm_raw,
        "norm_physical_raw": norm_physical_raw,

        "l2": loss_l2,

        "lambda": model.lambda_,

        # Normalized physical integral: should be approximately one.
        "mass_norm_integral": norm_integral,

        # Raw network amplitude diagnostic.
        "raw_mass_norm_integral": raw_mass_norm_integral,

        "residual_rms": residual_rms,
        "operator_scale_rms": operator_scale_rms,
        "relative_residual_rms": relative_residual_rms,

        "max_abs_residual": torch.max(
            torch.abs(residual)
        ),
    }

    for key, value in bc.items():
        comp[key] = value

    # Diagnostics corresponding to the normalized mode.
    comp["phi_rms"] = (
        mode_scale
        * torch.sqrt(
            torch.mean(
                fields["phi"].square()
            )
        )
    )

    comp["mass_operator_rms"] = (
        mode_scale
        * torch.sqrt(
            torch.mean(
                fields["mass_operator"].square()
            )
        )
    )

    return total, comp

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 L2 penalty (Regularization)

# %%
# L2 implementation consistency check

if not hasattr(EigenPINN(Config()), "nn_phi"):
    raise RuntimeError(
        "EigenPINN must expose the neural network through 'nn_phi'."
    )

print("L2 implementation dependency check: OK")
# Out:
# L2 implementation dependency check: OK

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 PINN's Losses

# %%
# PINN loss API consistency check

import inspect

expected_parameters = (
    "model",
    "X_colloc_base",
    "X_quad",
    "W_quad",
    "cfg",
    "device",
)

actual_parameters = tuple(
    inspect.signature(compute_loss).parameters.keys()
)

if actual_parameters != expected_parameters:
    raise RuntimeError(
        "compute_loss API mismatch.\n"
        f"Expected: {expected_parameters}\n"
        f"Found   : {actual_parameters}"
    )

required_history_components = {
    "total",
    "de",
    "de_raw",
    "bc",
    "bc_raw",
    "norm",
    "norm_raw",
    "norm_physical_raw",
    "l2",
    "lambda",
    "mass_norm_integral",
    "raw_mass_norm_integral",
    "residual_rms",
    "operator_scale_rms",
    "relative_residual_rms",
    "max_abs_residual",
    "phi_0",
    "dphi_0",
    "ddphi_0",
    "phi_1",
    "dphi_1",
    "ddphi_1",
    "moment_1",
    "shear_1",
    "phi_rms",
    "mass_operator_rms",
}

# Execute a lightweight real call to compute_loss and verify its output API.
# Preserve the CPU RNG state so this check does not affect later training.
_rng_state = torch.get_rng_state()

try:
    _cfg_check = Config()
    _device_check = torch.device("cpu")
    _model_check = EigenPINN(_cfg_check).to(_device_check)

    _X_colloc_check = torch.linspace(
        _cfg_check.x_min,
        _cfg_check.x_max,
        18,
        dtype=torch.float64,
        device=_device_check,
    )[1:-1].reshape(-1, 1)

    _X_quad_check, _W_quad_check = gauss_legendre_tensors(
        n=16,
        device=_device_check,
        x_min=_cfg_check.x_min,
        x_max=_cfg_check.x_max,
    )

    _, _comp_check = compute_loss(
        model=_model_check,
        X_colloc_base=_X_colloc_check,
        X_quad=_X_quad_check,
        W_quad=_W_quad_check,
        cfg=_cfg_check,
        device=_device_check,
    )

    missing_components = (
        required_history_components
        - set(_comp_check.keys())
    )

    if missing_components:
        raise RuntimeError(
            "compute_loss output is missing required components:\n"
            f"{sorted(missing_components)}"
        )

finally:
    torch.set_rng_state(_rng_state)

print("compute_loss signature:", inspect.signature(compute_loss))
print("PINN loss API consistency check: OK")
# Out:
# compute_loss signature: (model: 'EigenPINN', X_colloc_base: 'torch.Tensor', X_quad: 'torch.Tensor', W_quad: 'torch.Tensor', cfg: 'Config', device: 'torch.device') -> 'Tuple[torch.Tensor, Dict[str, torch.Tensor]]'
# PINN loss API consistency check: OK

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 History/checkpoint utilities

# %%
# History/checkpoint utilities

PHYSICS_HISTORY_KEYS = [
    "total",
    "de",
    "de_raw",

    "bc",
    "bc_raw",

    "norm",
    "norm_raw",
    "norm_physical_raw",

    "l2",
    "lambda",

    "mass_norm_integral",
    "raw_mass_norm_integral",

    "residual_rms",
    "operator_scale_rms",
    "relative_residual_rms",
    "max_abs_residual",

    "phi_0",
    "dphi_0",
    "ddphi_0",

    "phi_1",
    "dphi_1",
    "ddphi_1",
    "moment_1",
    "shear_1",

    "phi_rms",
    "mass_operator_rms",
]

HISTORY_KEYS = [
    "optimization_step",
    "optimizer_phase",
    "phase_step",

    *PHYSICS_HISTORY_KEYS,

    "lr_nn",
    "lr_lambda",
    "lr_lbfgs",
    "lbfgs_func_evals",
]


def make_history() -> Dict[str, list]:
    return {
        key: []
        for key in HISTORY_KEYS
    }


def append_history(
    history: Dict[str, list],
    comp: Dict[str, torch.Tensor],
    optimization_step: int,
    optimizer_phase: str,
    phase_step: int,
    lr_nn: float = math.nan,
    lr_lambda: float = math.nan,
    lr_lbfgs: float = math.nan,
    lbfgs_func_evals: int = 0,
) -> None:
    """
    Append one accepted/recorded optimization state.

    Adam entries are recorded at the existing pre-update state.
    L-BFGS entries are recorded only at accepted block endpoints, never at
    transient strong-Wolfe line-search trial states.
    """
    history["optimization_step"].append(
        int(optimization_step)
    )

    history["optimizer_phase"].append(
        str(optimizer_phase)
    )

    history["phase_step"].append(
        int(phase_step)
    )

    for key in PHYSICS_HISTORY_KEYS:
        history[key].append(
            float(
                comp[key]
                .detach()
                .cpu()
            )
        )

    history["lr_nn"].append(
        float(lr_nn)
    )

    history["lr_lambda"].append(
        float(lr_lambda)
    )

    history["lr_lbfgs"].append(
        float(lr_lbfgs)
    )

    history["lbfgs_func_evals"].append(
        int(lbfgs_func_evals)
    )


def cpu_state_dict(
    model: nn.Module,
) -> Dict[str, torch.Tensor]:
    return {
        key: value.detach().cpu().clone()
        for key, value in model.state_dict().items()
    }


def _to_cpu_recursive(obj):
    if torch.is_tensor(obj):
        return obj.detach().cpu().clone()

    if isinstance(obj, dict):
        return {
            k: _to_cpu_recursive(v)
            for k, v in obj.items()
        }

    if isinstance(obj, list):
        return [
            _to_cpu_recursive(v)
            for v in obj
        ]

    if isinstance(obj, tuple):
        return tuple(
            _to_cpu_recursive(v)
            for v in obj
        )

    return copy.deepcopy(obj)


def cpu_optimizer_state_dict(
    optimizer: torch.optim.Optimizer,
) -> dict:
    return _to_cpu_recursive(
        optimizer.state_dict()
    )


def save_history_csv(
    history: Dict[str, list],
    output_dir: Path,
) -> None:
    df = pd.DataFrame(
        history
    )

    df.to_csv(
        output_dir / "training_history.csv",
        index=False,
    )

    for key, values in history.items():
        pd.DataFrame(
            {key: values}
        ).to_csv(
            output_dir / f"history_{key}.csv",
            index=False,
        )

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Prediction and plotting

# %%
# Prediction and plotting

PINN_COLOR = "purple"
REFERENCE_COLOR = "black"

# Publication-style colors for the three physics-informed loss components
TOTAL_LOSS_COLOR = "#0B3C5D"  # dark blue
DE_LOSS_COLOR = "#C62828"     # red
BC_LOSS_COLOR = "#2E7D32"     # green

# Black is retained for scalar convergence diagnostics
DIAGNOSTIC_COLOR = "black"

# Visual marker for the optimizer handoff
PHASE_TRANSITION_COLOR = "0.45"


def predict(
    model: EigenPINN,
    X: torch.Tensor,
) -> np.ndarray:
    model.eval()

    with torch.no_grad():
        return (
            model(X)
            .detach()
            .cpu()
            .numpy()
            .reshape(-1)
        )


def maxabs_normalize_mode(
    y: np.ndarray,
) -> np.ndarray:
    """
    Normalize a mode shape by its maximum absolute amplitude.

    A deterministic sign convention is used only for visualization:
    the largest-magnitude point is made positive.
    """
    y = np.asarray(
        y,
        dtype=np.float64,
    ).reshape(-1)

    scale = float(
        np.max(np.abs(y))
    )

    if scale < 1.0e-14:
        return y.copy()

    out = y / scale

    idx = int(
        np.argmax(np.abs(out))
    )

    if out[idx] < 0.0:
        out = -out

    return out


def _align_reference_for_plot(
    phi_pinn: np.ndarray,
    phi_ref: np.ndarray,
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Max-absolute normalize PINN and reference modes and align their
    arbitrary global signs for visualization only.
    """
    p = maxabs_normalize_mode(
        phi_pinn
    )

    q = maxabs_normalize_mode(
        phi_ref
    )

    if p.size != q.size:
        raise ValueError(
            "PINN and reference mode arrays must have identical sizes."
        )

    if float(np.dot(p, q)) < 0.0:
        q = -q

    return p, q


def _optimizer_transition_step(
    history: Dict[str, list],
) -> Optional[float]:
    """
    Return the actual Adam-to-L-BFGS handoff step.

    The handoff occurs immediately after the final recorded Adam step,
    before the first accepted L-BFGS block-end state.
    """
    phases = history.get(
        "optimizer_phase",
        [],
    )

    steps = history.get(
        "optimization_step",
        [],
    )

    if len(phases) != len(steps):
        raise ValueError(
            "optimizer_phase and optimization_step history lengths are inconsistent."
        )

    adam_steps = [
        float(step)
        for phase, step in zip(phases, steps)
        if str(phase).strip().upper() == "ADAM"
    ]

    has_lbfgs = any(
        str(phase).strip().upper() == "L-BFGS"
        for phase in phases
    )

    if has_lbfgs and adam_steps:
        return max(adam_steps)

    return None


def _add_optimizer_transition_marker(
    ax,
    transition_step: Optional[float],
) -> None:
    """
    Add a publication-style Adam -> L-BFGS transition marker.
    """
    if transition_step is None:
        return

    ax.axvline(
        transition_step,
        color=PHASE_TRANSITION_COLOR,
        linestyle=":",
        linewidth=1.25,
        alpha=0.90,
        zorder=0,
    )

    ax.text(
        transition_step,
        0.97,
        "Adam → L-BFGS",
        transform=ax.get_xaxis_transform(),
        fontsize=8.8,
        color=PHASE_TRANSITION_COLOR,
        rotation=90,
        verticalalignment="top",
        horizontalalignment="right",
    )


def plot_snapshot(
    model: EigenPINN,
    X_test: torch.Tensor,
    history: Dict[str, list],
    optimization_step: int,
    output_path: Path,
    reference_x: Optional[np.ndarray] = None,
    reference_phi: Optional[np.ndarray] = None,
    reference_lambda: Optional[float] = None,
) -> None:
    """
    Save one compact publication-oriented C-F hybrid-training snapshot.

    The four retained panels are:

        1. Eigenfunction Comparison
        2. Trainable Eigenvalue
        3. Physics-Informed Loss Components
        4. Relative PDE Residual RMS

    The history axis uses the global optimization-step coordinate rather
    than an Adam-only epoch count. During the L-BFGS phase, only accepted
    recorded states are shown; transient strong-Wolfe line-search trial
    evaluations are not plotted.

    If an independent BVP mode is supplied:

        PINN            : purple solid line
        Independent BVP : black dashed line

    The BVP reference is used only for visualization and does not enter
    the PINN loss, optimization, optimizer switching, or checkpointing.
    """

    if optimization_step < 1:
        raise ValueError(
            "optimization_step must be positive."
        )

    n_history = len(
        history["total"]
    )

    if n_history < 1:
        raise ValueError(
            "Training history is empty."
        )

    # Consistency checks for phase-aware history
    required_plot_keys = (
        "optimization_step",
        "optimizer_phase",
        "total",
        "de",
        "bc",
        "lambda",
        "relative_residual_rms",
    )

    for key in required_plot_keys:
        if key not in history:
            raise KeyError(
                f"Required plotting history key is missing: {key}"
            )

        if len(history[key]) != n_history:
            raise ValueError(
                f"History length mismatch for key '{key}'."
            )

    steps = np.asarray(
        history["optimization_step"],
        dtype=np.float64,
    )

    if np.any(~np.isfinite(steps)):
        raise ValueError(
            "Non-finite optimization_step values detected."
        )

    if np.any(np.diff(steps) <= 0.0):
        raise ValueError(
            "optimization_step history must be strictly increasing."
        )

    transition_step = _optimizer_transition_step(
        history
    )

    x = (
        X_test
        .detach()
        .cpu()
        .numpy()
        .reshape(-1)
    )

    phi_pinn_raw = predict(
        model,
        X_test,
    )

    phi_pinn_plot = maxabs_normalize_mode(
        phi_pinn_raw
    )

    phi_ref_plot = None

    # Optional independent BVP reference
    if (
        reference_x is not None
        and reference_phi is not None
    ):
        reference_x = np.asarray(
            reference_x,
            dtype=np.float64,
        ).reshape(-1)

        reference_phi = np.asarray(
            reference_phi,
            dtype=np.float64,
        ).reshape(-1)

        if (
            reference_x.size != x.size
            or not np.allclose(
                reference_x,
                x,
                rtol=0.0,
                atol=1.0e-13,
            )
        ):
            raise ValueError(
                "Snapshot reference must be evaluated on the same X_test grid."
            )

        (
            phi_pinn_plot,
            phi_ref_plot,
        ) = _align_reference_for_plot(
            phi_pinn_raw,
            reference_phi,
        )

    # Figure
    fig, axes = plt.subplots(
        2,
        2,
        figsize=(13.2, 9.0),
        constrained_layout=True,
    )

    fig.patch.set_facecolor(
        "white"
    )

    def format_axis(
        ax,
        grid: bool = True,
    ) -> None:
        ax.tick_params(
            axis="both",
            labelsize=10,
        )

        if grid:
            ax.grid(
                True,
                which="both",
                linestyle=":",
                linewidth=0.7,
                alpha=0.35,
            )

    # (a) Eigenfunction Comparison
    ax = axes[0, 0]

    ax.plot(
        x,
        phi_pinn_plot,
        color=PINN_COLOR,
        linewidth=2.5,
        linestyle="-",
        label="PINN",
    )

    if phi_ref_plot is not None:
        ax.plot(
            x,
            phi_ref_plot,
            color=REFERENCE_COLOR,
            linewidth=2.1,
            linestyle="--",
            label="Independent BVP",
        )

    ax.set_title(
        "Eigenfunction Comparison",
        fontsize=12,
        fontweight="semibold",
    )

    ax.set_xlabel(
        r"$X=x/L$",
        fontsize=11,
    )

    ax.set_ylabel(
        r"$\frac{\Phi(X)}{\max\left|\Phi(X)\right|}$",
        fontsize=11,
        labelpad=10,
    )

    ax.set_xlim(
        float(x[0]),
        float(x[-1]),
    )

    ax.legend(
        loc="best",
        fontsize=9.5,
        frameon=True,
    )

    format_axis(
        ax
    )

    # (b) Trainable Eigenvalue
    ax = axes[0, 1]

    lambda_vals = np.asarray(
        history["lambda"],
        dtype=np.float64,
    )

    ax.plot(
        steps,
        lambda_vals,
        color=DIAGNOSTIC_COLOR,
        linewidth=2.0,
    )

    _add_optimizer_transition_marker(
        ax,
        transition_step,
    )

    ax.set_title(
        "Trainable Eigenvalue",
        fontsize=12,
        fontweight="semibold",
    )

    ax.set_xlabel(
        "Optimization Step",
        fontsize=11,
    )

    ax.set_ylabel(
        r"$\lambda$",
        fontsize=11,
    )

    format_axis(
        ax
    )

    # (c) Physics-Informed Loss Components
    ax = axes[1, 0]

    total_vals = np.asarray(
        history["total"],
        dtype=np.float64,
    )

    de_vals = np.asarray(
        history["de"],
        dtype=np.float64,
    )

    bc_vals = np.asarray(
        history["bc"],
        dtype=np.float64,
    )

    floor = 1.0e-300

    ax.plot(
        steps,
        np.maximum(
            total_vals,
            floor,
        ),
        color=TOTAL_LOSS_COLOR,
        linewidth=2.1,
        linestyle="-",
        label="Total Loss",
    )

    ax.plot(
        steps,
        np.maximum(
            de_vals,
            floor,
        ),
        color=DE_LOSS_COLOR,
        linewidth=1.9,
        linestyle="--",
        label="DE Loss",
    )

    ax.plot(
        steps,
        np.maximum(
            bc_vals,
            floor,
        ),
        color=BC_LOSS_COLOR,
        linewidth=1.9,
        linestyle="-.",
        label="BC Loss",
    )

    _add_optimizer_transition_marker(
        ax,
        transition_step,
    )

    ax.set_yscale(
        "log"
    )

    ax.set_title(
        "Physics-Informed Loss Components",
        fontsize=12,
        fontweight="semibold",
    )

    ax.set_xlabel(
        "Optimization Step",
        fontsize=11,
    )

    ax.set_ylabel(
        r"$\mathcal{L}$",
        fontsize=11,
    )

    ax.legend(
        loc="best",
        fontsize=9.5,
        frameon=True,
    )

    format_axis(
        ax
    )

    # (d) Relative PDE Residual RMS
    ax = axes[1, 1]

    relative_residual = np.asarray(
        history["relative_residual_rms"],
        dtype=np.float64,
    )

    ax.plot(
        steps,
        np.maximum(
            relative_residual,
            1.0e-300,
        ),
        color=DIAGNOSTIC_COLOR,
        linewidth=2.0,
    )

    _add_optimizer_transition_marker(
        ax,
        transition_step,
    )

    ax.set_yscale(
        "log"
    )

    ax.set_title(
        "Relative PDE Residual RMS",
        fontsize=12,
        fontweight="semibold",
    )

    ax.set_xlabel(
        "Optimization Step",
        fontsize=11,
    )

    ax.set_ylabel(
        r"$R_{\mathrm{rel,RMS}}$",
        fontsize=11,
    )

    format_axis(
        ax
    )

    fig.savefig(
        output_path,
        dpi=200,
        facecolor="white",
        transparent=False,
        bbox_inches="tight",
        pad_inches=0.16,
    )

    plt.close(
        fig
    )


def plot_final_mode_comparison(
    X: np.ndarray,
    phi_pinn: np.ndarray,
    lambda_pinn: float,
    optimization_step: int,
    output_path: Path,
    phi_ref: Optional[np.ndarray] = None,
    lambda_ref: Optional[float] = None,
) -> None:
    """
    Publication-style final C-F eigenfunction comparison.

    Purple solid line : PINN.
    Black dashed line : independent BVP.

    The optimization-step number is intentionally not displayed in the
    final figure.
    """

    X = np.asarray(
        X,
        dtype=np.float64,
    ).reshape(-1)

    phi_pinn = np.asarray(
        phi_pinn,
        dtype=np.float64,
    ).reshape(-1)

    if X.size != phi_pinn.size:
        raise ValueError(
            "X and phi_pinn must have identical sizes."
        )

    phi_pinn_plot = maxabs_normalize_mode(
        phi_pinn
    )

    phi_ref_plot = None

    if phi_ref is not None:
        phi_ref = np.asarray(
            phi_ref,
            dtype=np.float64,
        ).reshape(-1)

        if phi_ref.size != X.size:
            raise ValueError(
                "phi_ref must be evaluated on the same grid as phi_pinn."
            )

        (
            phi_pinn_plot,
            phi_ref_plot,
        ) = _align_reference_for_plot(
            phi_pinn,
            phi_ref,
        )

    fig, ax = plt.subplots(
        figsize=(9.2, 6.2),
        constrained_layout=True,
    )

    fig.patch.set_facecolor(
        "white"
    )

    ax.plot(
        X,
        phi_pinn_plot,
        color=PINN_COLOR,
        linewidth=2.8,
        linestyle="-",
        label="PINN",
    )

    if phi_ref_plot is not None:
        ax.plot(
            X,
            phi_ref_plot,
            color=REFERENCE_COLOR,
            linewidth=2.3,
            linestyle="--",
            label="Independent BVP",
        )

    ax.set_title(
        "Eigenfunction Comparison",
        fontsize=14,
        fontweight="semibold",
        pad=12,
    )

    ax.set_xlabel(
        r"$X=x/L$",
        fontsize=12,
        labelpad=7,
    )

    ax.set_ylabel(
        r"$\frac{\Phi(X)}{\max\left|\Phi(X)\right|}$",
        fontsize=12,
        labelpad=10,
    )

    ax.set_xlim(
        float(X[0]),
        float(X[-1]),
    )

    ax.tick_params(
        axis="both",
        labelsize=11,
    )

    ax.grid(
        True,
        linestyle=":",
        linewidth=0.75,
        alpha=0.35,
    )

    ax.legend(
        loc="best",
        fontsize=11,
        frameon=True,
    )

    # Keep only the physically relevant PINN eigenvalue annotation.
    ax.text(
        0.03,
        0.96,
        rf"$\lambda_{{\rm PINN}} = {lambda_pinn:.6f}$",
        transform=ax.transAxes,
        fontsize=10.5,
        verticalalignment="top",
        horizontalalignment="left",
        bbox={
            "boxstyle": "round,pad=0.35",
            "facecolor": "white",
            "edgecolor": "0.70",
            "alpha": 0.92,
        },
    )

    fig.savefig(
        output_path,
        dpi=220,
        facecolor="white",
        transparent=False,
        bbox_inches="tight",
        pad_inches=0.18,
    )

    plt.close(
        fig
    )


def save_coefficient_profiles(
    cfg: Config,
    output_dir: Path,
) -> None:
    X = np.linspace(
        0.0,
        1.0,
        501,
    )

    sec = section_resultants_numpy(
        X,
        cfg,
    )

    df = pd.DataFrame(
        {
            "X": X,
            **sec,
        }
    )

    df["zE_over_h"] = (
        df["zE"]
        / cfg.h
    )

    df["zrho_over_h"] = (
        df["zrho"]
        / cfg.h
    )

    df.to_csv(
        output_dir / "coefficient_profiles.csv",
        index=False,
    )

    fig, axes = plt.subplots(
        1,
        2,
        figsize=(11.5, 4.8),
        constrained_layout=True,
    )

    fig.patch.set_facecolor(
        "white"
    )

    ax1 = axes[0]

    ax1.plot(
        X,
        sec["d"],
        linewidth=2.0,
        label=r"$d(X)=D^\star/D_0$",
    )

    ax1.plot(
        X,
        sec["r"],
        linewidth=2.0,
        label=r"$r(X)=I_0^\rho/m_0$",
    )

    ax1.set_xlabel(
        r"$X=x/L$",
        fontsize=11,
    )

    ax1.set_title(
        "Dimensionless Coefficient Profiles",
        fontsize=12,
        fontweight="semibold",
    )

    ax1.grid(
        True,
        linestyle=":",
        linewidth=0.7,
        alpha=0.35,
    )

    ax1.legend(
        fontsize=10,
        frameon=True,
    )

    ax2 = axes[1]

    ax2.plot(
        X,
        sec["zE"] / cfg.h,
        linewidth=2.0,
        label="Elastic neutral axis",
    )

    ax2.plot(
        X,
        sec["zrho"] / cfg.h,
        linewidth=2.0,
        label="Mass centroid",
    )

    ax2.set_xlabel(
        r"$X=x/L$",
        fontsize=11,
    )

    ax2.set_ylabel(
        r"$z/h$",
        fontsize=11,
    )

    ax2.set_title(
        "Elastic Neutral Axis and Mass Centroid",
        fontsize=12,
        fontweight="semibold",
    )

    ax2.grid(
        True,
        linestyle=":",
        linewidth=0.7,
        alpha=0.35,
    )

    ax2.legend(
        fontsize=10,
        frameon=True,
    )

    fig.savefig(
        output_dir / "coefficient_profiles.png",
        dpi=180,
        facecolor="white",
        transparent=False,
        bbox_inches="tight",
        pad_inches=0.16,
    )

    plt.close(
        fig
    )

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Physical frequency conversion

# %%
# Physical frequency conversion

def lambda_to_omega(lambda_value: float, cfg: Config) -> float:
    return math.sqrt(lambda_value * cfg.D0 / (cfg.m0 * cfg.L**4))


def lambda_to_frequency_hz(lambda_value: float, cfg: Config) -> float:
    return lambda_to_omega(lambda_value, cfg) / (2.0 * math.pi)

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Independent post-training BVP reference solver

# %%
# Independent BVP reference solver

def _falling_power_derivative(
    X: np.ndarray,
    exponent: float,
    order: int,
) -> np.ndarray:
    """
    Compute d^order/dX^order (X^exponent).

    Integer powers are handled explicitly so that derivatives above the
    polynomial degree return exact zeros rather than expressions such as
    0 * X^negative_power.
    """
    X = np.asarray(X, dtype=np.float64)

    if order < 0:
        raise ValueError("Derivative order must be nonnegative.")

    if order == 0:
        return np.power(X, exponent)

    is_integer = abs(exponent - round(exponent)) < 1.0e-12
    n_int = int(round(exponent)) if is_integer else None

    if is_integer and order > n_int:
        return np.zeros_like(X)

    coeff = 1.0
    for j in range(order):
        coeff *= exponent - j

    if abs(coeff) < 1.0e-15:
        return np.zeros_like(X)

    with np.errstate(divide="ignore", invalid="ignore", over="ignore"):
        result = coeff * np.power(X, exponent - order)

    return result


def coefficient_derivatives_numpy(
    X: np.ndarray,
    cfg: Config,
) -> Tuple[np.ndarray, ...]:
    """
    Return

        d, d', d'', d''', r, r', r''

    analytically for the independent expanded-form BVP solver.
    """
    X = np.asarray(X, dtype=np.float64)

    q = _falling_power_derivative(X, cfg.k, 0)
    q1 = _falling_power_derivative(X, cfg.k, 1)
    q2 = _falling_power_derivative(X, cfg.k, 2)
    q3 = _falling_power_derivative(X, cfg.k, 3)

    cA, cB, cD = _section_constants(cfg)

    eta_E = (cfg.E_m - cfg.E_c) / cfg.E_c
    eta_rho = (cfg.rho_m - cfg.rho_c) / cfg.rho_c

    # Dimensionless condensed bending stiffness
    #
    # d(q) = 1 + A q - B q^2 / (1 + C q)
    A = 12.0 * eta_E * cD
    B = 12.0 * eta_E**2 * cB**2
    C = eta_E * cA

    den = 1.0 + C * q

    if np.any(~np.isfinite(den)) or np.any(np.abs(den) < 1.0e-14):
        raise ValueError(
            "Invalid denominator encountered in dimensionless stiffness."
        )

    g = q**2 / den

    # Derivatives of g(q) = q^2 / (1 + C q)
    gq = q * (C * q + 2.0) / den**2
    gqq = 2.0 / den**3
    gqqq = -6.0 * C / den**4

    # Derivatives of d with respect to q
    fq = A - B * gq
    fqq = -B * gqq
    fqqq = -B * gqqq

    # Chain-rule derivatives with respect to X
    d = 1.0 + A * q - B * g

    d1 = fq * q1

    d2 = (
        fqq * q1**2
        + fq * q2
    )

    d3 = (
        fqqq * q1**3
        + 3.0 * fqq * q1 * q2
        + fq * q3
    )

    # Dimensionless mass coefficient
    # r(X) = 1 + R X^k
    R = eta_rho * cA

    r = 1.0 + R * q
    r1 = R * q1
    r2 = R * q2

    return d, d1, d2, d3, r, r1, r2


def _base_cf_polynomial_derivative(
    X: np.ndarray,
    order: int,
) -> np.ndarray:
    """
    Derivatives of the smooth C-F initial-guess function

        Phi_0(X) = X^3 (2-X),

    used only as the initial shape guess for solve_bvp.

    It satisfies

        Phi(0) = Phi'(0) = Phi''(0) = 0,
        Phi''(1) = 0,

    while leaving the free-end displacement and slope unconstrained.
    """
    X = np.asarray(X, dtype=np.float64)

    if order < 0:
        raise ValueError("Derivative order must be nonnegative.")

    # X^3(2-X) = 2X^3 - X^4
    terms = [
        (3, 2.0),
        (4, -1.0),
    ]

    out = np.zeros_like(X)

    for power, coeff0 in terms:
        if order > power:
            continue

        coeff = coeff0

        for j in range(order):
            coeff *= power - j

        out += coeff * X ** (power - order)

    return out


def reference_bvp_is_regular(cfg: Config) -> bool:
    """
    Check endpoint regularity of the expanded BVP coefficients.

    The expanded strong form requires d''' and r''. For noninteger k < 3,
    these derivatives may become singular at X = 0.
    """
    is_integer_k = abs(cfg.k - round(cfg.k)) < 1.0e-12

    return is_integer_k or cfg.k >= 3.0


def count_interior_nodes(
    X: np.ndarray,
    phi: np.ndarray,
    relative_tol: float = 1.0e-7,
) -> int:
    """
    Count sign-changing interior nodes of a mode shape.

    Values smaller than relative_tol * max|phi| are ignored to avoid
    counting numerical roundoff, including an imposed boundary zero, as
    a physical node. A nonzero free-end value is retained.
    """
    X = np.asarray(X, dtype=np.float64).reshape(-1)
    phi = np.asarray(phi, dtype=np.float64).reshape(-1)

    if X.size != phi.size:
        raise ValueError("X and phi must have identical sizes.")

    if X.size < 3:
        return 0

    if not np.all(np.isfinite(phi)):
        raise ValueError("Non-finite mode-shape values encountered.")

    amplitude = float(np.max(np.abs(phi)))

    if amplitude < 1.0e-14:
        return 0

    tol = relative_tol * amplitude

    # Remove values numerically indistinguishable from zero. This removes
    # the clamped-end boundary zero while retaining a nonzero free-end value.
    phi_sig = phi[np.abs(phi) > tol]

    if phi_sig.size < 2:
        return 0

    signs = np.sign(phi_sig)

    return int(
        np.sum(signs[:-1] * signs[1:] < 0.0)
    )


def solve_reference_bvp_cf(cfg: Config) -> Optional[dict]:
    """
    Independent SciPy solve_bvp validation of the same sixth-order C-F model.

    This solver provides an independent BVP reference for visualization
    and validation.

    State vector:

        Y = [Phi, Phi', Phi'', Phi''', Phi'''', Phi''''', I]^T

    where the seventh state satisfies

        I'(X) = r(X) Phi(X)^2.

    Lambda is treated as an unknown BVP parameter.

    The eight constraints consist of the six C-F conditions

        Phi(0) = Phi'(0) = Phi''(0) = 0,
        Phi''(1) = 0,
        Mbar(1) = 0,
        Mbar'(1) = 0,

    plus

        I(0) = 0,
        I(1) = 1.

    The BVP reference is therefore independently mass-normalized.
    """
    if not cfg.run_reference_bvp:
        return None

    if not SCIPY_AVAILABLE:
        LOGGER.warning(
            "SciPy unavailable: skipping independent BVP validation."
        )
        return None

    if not reference_bvp_is_regular(cfg):
        LOGGER.warning(
            "Skipping BVP validation because fractional k < 3 produces "
            "endpoint-singular coefficient derivatives in the expanded "
            "strong form."
        )
        return None

    if cfg.zeta <= 0.0:
        LOGGER.warning(
            "Skipping sixth-order BVP validation because zeta must be positive."
        )
        return None

    # The present nondimensional formulation is defined over X in [0, 1].
    x = np.linspace(
        0.0,
        1.0,
        201,
        dtype=np.float64,
    )

    d0, _, _, _, r0, _, _ = coefficient_derivatives_numpy(
        x,
        cfg,
    )

    if (
        np.any(~np.isfinite(d0))
        or np.any(~np.isfinite(r0))
        or np.min(d0) <= 0.0
        or np.min(r0) <= 0.0
    ):
        LOGGER.warning(
            "Invalid stiffness or mass coefficients detected; "
            "BVP validation skipped."
        )
        return None

    # Initial C-F first-mode-like shape
    # Phi_0(X) = X^3(2-X)
    # This already satisfies
    # Phi(0) = Phi'(0) = Phi''(0) = 0
    # Phi''(1) = 0
    # but it is not required to satisfy the free-end moment and shear
    # conditions exactly as an initial solve_bvp guess.
    base = _base_cf_polynomial_derivative(
        x,
        order=0,
    )

    norm0 = np.trapezoid(
        r0 * base**2,
        x,
    )

    if not np.isfinite(norm0) or norm0 <= 1.0e-300:
        LOGGER.warning(
            "Invalid initial BVP normalization integral."
        )
        return None

    scale = 1.0 / math.sqrt(norm0)

    y0 = np.zeros(
        (7, x.size),
        dtype=np.float64,
    )

    for j in range(6):
        y0[j, :] = (
            scale
            * _base_cf_polynomial_derivative(
                x,
                order=j,
            )
        )

    y0[6, :] = cumulative_trapezoid(
        r0 * y0[0] ** 2,
        x,
        initial=0.0,
    )

    # Expanded first-order ODE system
    def ode(
        X: np.ndarray,
        Y: np.ndarray,
        p: np.ndarray,
    ) -> np.ndarray:
        lam = float(p[0])

        (
            d,
            d1,
            d2,
            d3,
            r,
            r1,
            r2,
        ) = coefficient_derivatives_numpy(
            X,
            cfg,
        )

        (
            phi,
            phi1,
            phi2,
            phi3,
            phi4,
            phi5,
            integ,
        ) = Y

        # Generalized nonlocal mass operator:
        mass_operator = (
            r * phi
            - cfg.tau**2
            * (
                r * phi2
                + 2.0 * r1 * phi1
                + r2 * phi
            )
        )

        """
        Governing equation:
        
        d Phi'''' + 2d' Phi''' + d'' Phi''
        
        - zeta^2 [
            d Phi'''''' +
            3d' Phi''''' +
            3d'' Phi'''' +
            d''' Phi'''
          ]
        
        - lambda M[Phi] = 0
        
        Solving explicitly for Phi'''''':
        """
        numerator_phi6 = (
            d * phi4
            + 2.0 * d1 * phi3
            + d2 * phi2
            - cfg.zeta**2
            * (
                3.0 * d1 * phi5
                + 3.0 * d2 * phi4
                + d3 * phi3
            )
            - lam * mass_operator
        )

        phi6 = (
            numerator_phi6
            / (cfg.zeta**2 * d)
        )

        return np.vstack(
            (
                phi1,
                phi2,
                phi3,
                phi4,
                phi5,
                phi6,
                r * phi**2,
            )
        )

    # C-F boundary conditions + integral normalization
    # Coefficients required by Mbar(1) and Mbar'(1) are evaluated
    # independently at the free end X = 1.
    (
        d_1_bc,
        d1_1_bc,
        d2_1_bc,
        _,
        r_1_bc,
        r1_1_bc,
        _,
    ) = coefficient_derivatives_numpy(
        np.array(
            [1.0],
            dtype=np.float64,
        ),
        cfg,
    )

    d_1_bc = float(d_1_bc[0])
    d1_1_bc = float(d1_1_bc[0])
    d2_1_bc = float(d2_1_bc[0])
    r_1_bc = float(r_1_bc[0])
    r1_1_bc = float(r1_1_bc[0])

    def bc(
        ya: np.ndarray,
        yb: np.ndarray,
        p: np.ndarray,
    ) -> np.ndarray:
        lam = float(p[0])

        """
        Free-end physical moment
        
        Mbar
        = -d Phi''
          + zeta^2 (d Phi''')'
          - tau^2 lambda r Phi
        
        Hence at X=1:
        
        Mbar(1)
        = -d Phi''
          + zeta^2 [d' Phi''' + d Phi'''']
          - tau^2 lambda r Phi.
        """
        moment_1 = (
            -d_1_bc * yb[2]
            + cfg.zeta**2
            * (
                d1_1_bc * yb[3]
                + d_1_bc * yb[4]
            )
            - cfg.tau**2
            * lam
            * r_1_bc
            * yb[0]
        )

        """
        Free-end shear/resultant
        
        Mbar'
        = -d' Phi'' - d Phi'''
          + zeta^2 [
              d'' Phi'''
              + 2d' Phi''''
              + d Phi'''''
            ]
          - tau^2 lambda [
              r' Phi
              + r Phi'
            ].
        """
        shear_1 = (
            -d1_1_bc * yb[2]
            - d_1_bc * yb[3]
            + cfg.zeta**2
            * (
                d2_1_bc * yb[3]
                + 2.0 * d1_1_bc * yb[4]
                + d_1_bc * yb[5]
            )
            - cfg.tau**2
            * lam
            * (
                r1_1_bc * yb[0]
                + r_1_bc * yb[1]
            )
        )

        return np.array(
            [
                ya[0],
                ya[1],
                ya[2],

                yb[2],
                moment_1,
                shear_1,

                ya[6],
                yb[6] - 1.0,
            ],
            dtype=np.float64,
        )

    # Independent eigenvalue guesses
    guess_factors = (
        0.5,
        1.0,
        2.0,
    )

    guesses = [
        factor * cfg.reference_lambda_guess
        for factor in guess_factors
    ]

    candidates = []

    # Dense grid used only to characterize converged mode shapes.
    x_check = np.linspace(
        0.0,
        1.0,
        2001,
        dtype=np.float64,
    )

    for guess in guesses:
        try:
            sol = solve_bvp(
                ode,
                bc,
                x,
                y0.copy(),
                p=np.array(
                    [guess],
                    dtype=np.float64,
                ),
                tol=cfg.reference_tol,
                max_nodes=cfg.reference_max_nodes,
                verbose=0,
            )

        except Exception as exc:
            LOGGER.warning(
                "BVP attempt with lambda guess %.6g failed: %s",
                guess,
                exc,
            )
            continue

        if (
            sol.status != 0
            or sol.p is None
            or not np.isfinite(sol.p[0])
            or sol.p[0] <= 0.0
            or not np.all(np.isfinite(sol.y))
        ):
            continue

        phi_candidate = sol.sol(x_check)[0]

        if not np.all(np.isfinite(phi_candidate)):
            continue

        n_nodes = count_interior_nodes(
            x_check,
            phi_candidate,
        )

        candidates.append(
            {
                "solution": sol,
                "lambda": float(sol.p[0]),
                "interior_nodes": int(n_nodes),
                "initial_guess": float(guess),
            }
        )

        LOGGER.info(
            "BVP candidate: guess=%.6g | lambda=%.12f | "
            "interior_nodes=%d | mesh_nodes=%d | max_rms=%.3e",
            guess,
            float(sol.p[0]),
            n_nodes,
            sol.x.size,
            float(np.max(sol.rms_residuals)),
        )

    if not candidates:
        LOGGER.warning(
            "Independent BVP solver did not converge to a positive eigenpair."
        )
        return None

    # First-mode-like identification
    first_mode_candidates = [
        candidate
        for candidate in candidates
        if candidate["interior_nodes"] == 0
    ]

    if not first_mode_candidates:
        LOGGER.warning(
            "Positive BVP eigenpairs were obtained, but none could be "
            "identified as a zero-interior-node fundamental-mode candidate."
        )
        return None

    # Among zero-node converged solutions, choose the smallest positive
    # eigenvalue.
    selected = min(
        first_mode_candidates,
        key=lambda item: item["lambda"],
    )

    sol = selected["solution"]
    lam = selected["lambda"]

    # Independent dense-grid verification of the BVP normalization
    phi_check = sol.sol(x_check)[0]

    r_check = section_resultants_numpy(
        x_check,
        cfg,
    )["r"]

    mass_norm_check = np.trapezoid(
        r_check * phi_check**2,
        x_check,
    )

    LOGGER.info(
        "Independent first-mode BVP validation converged: "
        "lambda_ref=%.12f | interior_nodes=%d | mesh_nodes=%d | "
        "max_rms=%.3e | mass_norm=%.12f",
        lam,
        selected["interior_nodes"],
        sol.x.size,
        float(np.max(sol.rms_residuals)),
        float(mass_norm_check),
    )

    return {
        "solution": sol,
        "lambda": float(lam),
        "mode_number": 1,
        "interior_nodes": int(selected["interior_nodes"]),
        "initial_guess": float(selected["initial_guess"]),
        "mass_norm_integral": float(mass_norm_check),
    }


def weighted_mode_metrics(
    X: np.ndarray,
    phi_pinn: np.ndarray,
    phi_ref: np.ndarray,
    cfg: Config,
) -> Dict[str, float]:
    """
    Compare PINN and reference eigenfunctions using the mass-weighted inner
    product.

    Both eigenfunctions are independently normalized according to

        integral r(X) Phi(X)^2 dX = 1

    before sign alignment and error evaluation.
    """
    X = np.asarray(
        X,
        dtype=np.float64,
    ).reshape(-1)

    p = np.asarray(
        phi_pinn,
        dtype=np.float64,
    ).reshape(-1)

    q = np.asarray(
        phi_ref,
        dtype=np.float64,
    ).reshape(-1)

    if not (
        X.size == p.size == q.size
    ):
        raise ValueError(
            "X, phi_pinn, and phi_ref must have identical sizes."
        )

    if X.size < 2:
        raise ValueError(
            "At least two spatial points are required."
        )

    if np.any(np.diff(X) <= 0.0):
        raise ValueError(
            "X must be strictly increasing."
        )

    if (
        not np.all(np.isfinite(X))
        or not np.all(np.isfinite(p))
        or not np.all(np.isfinite(q))
    ):
        raise ValueError(
            "Non-finite values encountered in mode-shape comparison."
        )

    r = section_resultants_numpy(
        X,
        cfg,
    )["r"]

    if (
        not np.all(np.isfinite(r))
        or np.min(r) <= 0.0
    ):
        raise ValueError(
            "Invalid mass-weighting coefficient r(X)."
        )

    # Independent mass normalization
    norm_p_sq = np.trapezoid(
        r * p**2,
        X,
    )

    norm_q_sq = np.trapezoid(
        r * q**2,
        X,
    )

    if (
        not np.isfinite(norm_p_sq)
        or norm_p_sq <= 1.0e-300
    ):
        raise ValueError(
            "PINN eigenfunction has an invalid mass norm."
        )

    if (
        not np.isfinite(norm_q_sq)
        or norm_q_sq <= 1.0e-300
    ):
        raise ValueError(
            "Reference eigenfunction has an invalid mass norm."
        )

    p = p / math.sqrt(norm_p_sq)
    q = q / math.sqrt(norm_q_sq)

    # Eigenfunctions are defined up to an arbitrary sign.
    # Align the reference mode with the PINN mode.
    inner = np.trapezoid(
        r * p * q,
        X,
    )

    if inner < 0.0:
        q = -q
        inner = -inner

    # Mass-weighted Modal Assurance Criterion
    mac = float(inner**2)

    # Protect against tiny quadrature roundoff outside [0, 1].
    mac = min(
        max(mac, 0.0),
        1.0,
    )

    # Mass-weighted relative L2 mode-shape error
    # Both modes are unit mass-normalized, so the reference denominator is 1.
    error_sq = np.trapezoid(
        r * (p - q) ** 2,
        X,
    )

    error_sq = max(
        float(error_sq),
        0.0,
    )

    rel_l2 = math.sqrt(
        error_sq
    )

    return {
        "mass_weighted_MAC": float(mac),
        "relative_L2_mode_error": float(rel_l2),
    }

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Training

# %%
# Training

def train(cfg: Config) -> Dict[str, object]:
    """
    Train the unsupervised eigenvalue PINN for the Reduced Flexural
    2D-FG Euler-Bernoulli-NSGT nanobeam with C-F fixed-curvature BCs.

    Optimization protocol
    ---------------------
    Stage I  : Adam for cfg.adam_epochs epochs.
    Stage II : deterministic full-batch L-BFGS refinement for up to
               cfg.lbfgs_max_iter quasi-Newton iterations.

    The optimizer switch is fixed a priori by cfg.adam_epochs.

    The same collocation points, quadrature points, physics-informed
    objective, boundary conditions, and normalization are used in both
    optimization stages.

    The independent BVP reference is never used in:
        - the PINN objective,
        - optimizer updates,
        - optimizer switching,
        - checkpoint selection,
        - optimizer stopping criteria.
    """

    # Configuration, reproducibility, and device
    validate_config(cfg)

    set_seed(
        cfg.seed,
        cfg.deterministic_torch,
    )

    device = resolve_device(
        cfg.device
    )

    # The present nondimensional formulation is defined on X = x/L in [0, 1].
    if not (
        math.isclose(
            cfg.x_min,
            0.0,
            rel_tol=0.0,
            abs_tol=1.0e-14,
        )
        and math.isclose(
            cfg.x_max,
            1.0,
            rel_tol=0.0,
            abs_tol=1.0e-14,
        )
    ):
        raise ValueError(
            "The present 2D-FG EB-NSGT formulation is defined on "
            "the nondimensional domain X=x/L in [0, 1]. "
            "Use x_min=0 and x_max=1."
        )

    LOGGER.info(
        "Using device: %s",
        device,
    )

    LOGGER.info(
        "Default dtype: %s",
        torch.get_default_dtype(),
    )

    LOGGER.info(
        "Model: Reduced Flexural 2D-FG Euler-Bernoulli-NSGT, "
        "C-F (cantilever) fixed-curvature BC"
    )

    LOGGER.info(
        "k=%.6g, beta=%.6g, tau=%.6g, zeta=%.6g, L/h=%.6g",
        cfg.k,
        cfg.beta,
        cfg.tau,
        cfg.zeta,
        cfg.L_over_h,
    )

    LOGGER.info(
        "Optimization protocol: Adam=%d epochs -> "
        "L-BFGS<=%d quasi-Newton iterations",
        cfg.adam_epochs,
        cfg.lbfgs_max_iter,
    )

    # Output directories
    output_dir = Path(
        cfg.output_dir
    )

    if output_dir.exists():
        if any(
            output_dir.iterdir()
        ):
            raise FileExistsError(
                f"Output directory already contains files: {output_dir}\n"
                "Use a new output_dir for a clean independent run."
            )
    else:
        output_dir.mkdir(
            parents=True,
            exist_ok=False,
        )

    plot_dir = (
        output_dir
        / "optimization_plots"
    )

    if (
        cfg.save_epoch_plots
        and cfg.plot_every > 0
    ):
        plot_dir.mkdir(
            parents=True,
            exist_ok=False,
        )

    # Save configuration and derived dimensional quantities
    config_dict = asdict(
        cfg
    )

    config_dict["derived"] = {
        "b": cfg.b,
        "L": cfg.L,
        "A": cfg.area,
        "I_g": cfg.I_g,
        "D0": cfg.D0,
        "m0": cfg.m0,
        "mu": cfg.mu,
        "ell": cfg.ell,

        # This is a nominal optimization-step budget only.
        # Adam epochs and L-BFGS iterations are not computationally equivalent.
        "nominal_optimization_budget": int(
            cfg.adam_epochs
            + cfg.lbfgs_max_iter
        ),
    }

    with open(
        output_dir / "config.json",
        "w",
        encoding="utf-8",
    ) as f:
        json.dump(
            config_dict,
            f,
            indent=2,
        )

    # Research-grade startup checks
    verify_closed_form_section_resultants(
        cfg
    )

    validate_coefficient_profiles(
        cfg
    )

    verify_compact_vs_expanded_operator(
        cfg,
        device,
    )

    save_coefficient_profiles(
        cfg,
        output_dir,
    )

    # Fixed full-batch collocation points
    # IMPORTANT:
    # These points are generated once and retained unchanged in BOTH Adam
    # and L-BFGS. Therefore every L-BFGS closure evaluates exactly the same
    # deterministic physics-informed objective.
    X_colloc = torch.linspace(
        cfg.x_min,
        cfg.x_max,
        cfg.n_colloc + 2,
        dtype=torch.float64,
        device=device,
    )[1:-1].reshape(-1, 1)

    # Fixed Gauss-Legendre quadrature
    X_quad, W_quad = gauss_legendre_tensors(
        n=cfg.n_quad,
        device=device,
        x_min=cfg.x_min,
        x_max=cfg.x_max,
    )

    # Dense evaluation grid
    X_test = torch.linspace(
        cfg.x_min,
        cfg.x_max,
        cfg.n_test,
        dtype=torch.float64,
        device=device,
    ).reshape(-1, 1)

    # Independent C-F BVP reference for visualization only
    # The reference is never used by either optimizer.
    snapshot_reference = None
    snapshot_reference_x = None
    snapshot_reference_phi = None
    snapshot_reference_lambda = None

    if (
        cfg.save_epoch_plots
        and cfg.plot_every > 0
        and cfg.run_reference_bvp
    ):
        try:
            snapshot_reference = solve_reference_bvp_cf(
                cfg
            )

            if snapshot_reference is not None:

                snapshot_reference_x = (
                    X_test
                    .detach()
                    .cpu()
                    .numpy()
                    .reshape(-1)
                )

                snapshot_reference_phi = (
                    snapshot_reference[
                        "solution"
                    ]
                    .sol(
                        snapshot_reference_x
                    )[0]
                    .reshape(-1)
                )

                snapshot_reference_lambda = float(
                    snapshot_reference[
                        "lambda"
                    ]
                )

                LOGGER.info(
                    "Live C-F snapshot reference prepared: "
                    "lambda_BVP = %.9f",
                    snapshot_reference_lambda,
                )

            else:
                LOGGER.warning(
                    "No C-F BVP reference is available "
                    "for live snapshot plots."
                )

        except Exception as exc:
            LOGGER.warning(
                "Failed to prepare C-F BVP reference "
                "for live snapshot plots: %s",
                exc,
            )

            snapshot_reference = None
            snapshot_reference_x = None
            snapshot_reference_phi = None
            snapshot_reference_lambda = None

    # PINN model
    model = EigenPINN(
        cfg
    ).to(
        device
    )

    LOGGER.info(
        "Trainable NN parameters: %d",
        sum(
            parameter.numel()
            for parameter
            in model.nn_phi.parameters()
            if parameter.requires_grad
        ),
    )

    LOGGER.info(
        "Total trainable parameters including lambda_raw: %d",
        sum(
            parameter.numel()
            for parameter
            in model.parameters()
            if parameter.requires_grad
        ),
    )

    LOGGER.info(
        "No reference eigenvalue/eigenfunction "
        "is used during optimization."
    )

    # History
    history = make_history()

    # Globally best physics-informed state across BOTH optimizer phases
    best = {
        "loss": math.inf,

        "optimization_step": 0,
        "optimizer_phase": "",
        "phase_step": 0,

        "model_state": None,
        "checkpoint_state": "",

        "optimizer_nn_state": None,
        "optimizer_lambda_state": None,

        "scheduler_nn_state": None,
        "scheduler_lambda_state": None,

        "optimizer_lbfgs_state": None,
    }

    def save_best_checkpoint() -> None:
        """
        Save the currently recorded global best state.

        The checkpoint contains whichever optimizer state corresponds to
        the phase in which the best physics-informed state was obtained.
        """
        torch.save(
            {
                "optimization_step": int(
                    best[
                        "optimization_step"
                    ]
                ),

                "optimizer_phase": str(
                    best[
                        "optimizer_phase"
                    ]
                ),

                "phase_step": int(
                    best[
                        "phase_step"
                    ]
                ),

                "best_loss": float(
                    best[
                        "loss"
                    ]
                ),

                "model_state_dict": (
                    best[
                        "model_state"
                    ]
                ),

                "optimizer_nn_state_dict": (
                    best[
                        "optimizer_nn_state"
                    ]
                ),

                "optimizer_lambda_state_dict": (
                    best[
                        "optimizer_lambda_state"
                    ]
                ),

                "scheduler_nn_state_dict": (
                    best[
                        "scheduler_nn_state"
                    ]
                ),

                "scheduler_lambda_state_dict": (
                    best[
                        "scheduler_lambda_state"
                    ]
                ),

                "optimizer_lbfgs_state_dict": (
                    best[
                        "optimizer_lbfgs_state"
                    ]
                ),

                "config": config_dict,

                "model_name": (
                    "Reduced Flexural "
                    "2D-FG EB-NSGT C-F"
                ),

                "checkpoint_state": str(
                    best[
                        "checkpoint_state"
                    ]
                ),

                "reference_used_in_training": False,
            },

            output_dir
            / "best_checkpoint.pt",
        )

    def maybe_update_best(
        current_loss: float,
        optimization_step: int,
        optimizer_phase: str,
        phase_step: int,
        checkpoint_state: str,
        optimizer_nn: Optional[
            torch.optim.Optimizer
        ] = None,
        optimizer_lambda: Optional[
            torch.optim.Optimizer
        ] = None,
        scheduler_nn=None,
        scheduler_lambda=None,
        optimizer_lbfgs: Optional[
            torch.optim.Optimizer
        ] = None,
    ) -> None:
        """
        Update the global best model exclusively from the current
        physics-informed objective.

        No BVP quantity participates in this decision.
        """
        if current_loss >= best["loss"]:
            return

        best["loss"] = float(
            current_loss
        )

        best[
            "optimization_step"
        ] = int(
            optimization_step
        )

        best[
            "optimizer_phase"
        ] = str(
            optimizer_phase
        )

        best[
            "phase_step"
        ] = int(
            phase_step
        )

        best[
            "model_state"
        ] = cpu_state_dict(
            model
        )

        best[
            "checkpoint_state"
        ] = str(
            checkpoint_state
        )

        best[
            "optimizer_nn_state"
        ] = (
            None
            if optimizer_nn is None
            else cpu_optimizer_state_dict(
                optimizer_nn
            )
        )

        best[
            "optimizer_lambda_state"
        ] = (
            None
            if optimizer_lambda is None
            else cpu_optimizer_state_dict(
                optimizer_lambda
            )
        )

        best[
            "scheduler_nn_state"
        ] = (
            None
            if scheduler_nn is None
            else _to_cpu_recursive(
                scheduler_nn.state_dict()
            )
        )

        best[
            "scheduler_lambda_state"
        ] = (
            None
            if scheduler_lambda is None
            else _to_cpu_recursive(
                scheduler_lambda.state_dict()
            )
        )

        best[
            "optimizer_lbfgs_state"
        ] = (
            None
            if optimizer_lbfgs is None
            else cpu_optimizer_state_dict(
                optimizer_lbfgs
            )
        )

        save_best_checkpoint()

    # Stage I — Adam

    optimizer_nn = torch.optim.Adam(
        model.nn_phi.parameters(),
        lr=cfg.lr_nn,
    )

    optimizer_lambda = torch.optim.Adam(
        [
            model.lambda_raw
        ],
        lr=cfg.lr_lambda,
    )

    milestones = list(
        cfg.lr_milestones
    )

    scheduler_nn = (
        torch.optim.lr_scheduler.MultiStepLR(
            optimizer_nn,
            milestones=milestones,
            gamma=cfg.lr_gamma,
        )
    )

    scheduler_lambda = (
        torch.optim.lr_scheduler.MultiStepLR(
            optimizer_lambda,
            milestones=milestones,
            gamma=cfg.lr_gamma,
        )
    )

    LOGGER.info(
        "Adam LR milestones: %s; gamma=%.4g",
        milestones,
        cfg.lr_gamma,
    )

    # Adam loop
    for epoch_idx in range(
        cfg.adam_epochs
    ):

        model.train()

        optimizer_nn.zero_grad(
            set_to_none=True
        )

        optimizer_lambda.zero_grad(
            set_to_none=True
        )

        # PRE-update Adam physics-informed state
        total_loss, comp = compute_loss(
            model,
            X_colloc,
            X_quad,
            W_quad,
            cfg,
            device,
        )

        current_loss = float(
            total_loss
            .detach()
            .cpu()
        )

        epoch_number = (
            epoch_idx + 1
        )

        optimization_step = (
            epoch_number
        )

        if not math.isfinite(
            current_loss
        ):
            raise FloatingPointError(
                "Non-finite total loss at "
                f"Adam epoch {epoch_number}. "
                "Inspect coefficient regularity, "
                "learning rates, normalization, "
                "and high-order derivatives."
            )

        lr_nn_now = float(
            optimizer_nn
            .param_groups[0]["lr"]
        )

        lr_lambda_now = float(
            optimizer_lambda
            .param_groups[0]["lr"]
        )

        # Adam history
        append_history(
            history=history,
            comp=comp,

            optimization_step=(
                optimization_step
            ),

            optimizer_phase="Adam",

            phase_step=(
                epoch_number
            ),

            lr_nn=lr_nn_now,
            lr_lambda=lr_lambda_now,

            lr_lbfgs=math.nan,

            lbfgs_func_evals=0,
        )

        # Globally best checkpoint
        maybe_update_best(
            current_loss=current_loss,

            optimization_step=(
                optimization_step
            ),

            optimizer_phase="Adam",

            phase_step=(
                epoch_number
            ),

            checkpoint_state=(
                "adam_pre_update"
            ),

            optimizer_nn=(
                optimizer_nn
            ),

            optimizer_lambda=(
                optimizer_lambda
            ),

            scheduler_nn=(
                scheduler_nn
            ),

            scheduler_lambda=(
                scheduler_lambda
            ),

            optimizer_lbfgs=None,
        )

        # Adam logging
        if (
            cfg.log_every > 0
            and (
                epoch_number == 1
                or (
                    epoch_number
                    % cfg.log_every
                    == 0
                )
                or (
                    epoch_number
                    == cfg.adam_epochs
                )
            )
        ):
            LOGGER.info(
                "[Adam] epoch %d/%d | "
                "total=%.6e | "
                "DE=%.6e | "
                "BC=%.6e | "
                "Norm=%.6e | "
                "L2=%.3e | "
                "lambda=%.9f | "
                "int(r*phi^2)=%.8f | "
                "R_rms=%.3e | "
                "R_rel=%.3e | "
                "lr=(%.2e, %.2e)",

                epoch_number,
                cfg.adam_epochs,

                current_loss,

                float(
                    comp["de"]
                    .detach()
                    .cpu()
                ),

                float(
                    comp["bc"]
                    .detach()
                    .cpu()
                ),

                float(
                    comp["norm"]
                    .detach()
                    .cpu()
                ),

                float(
                    comp["l2"]
                    .detach()
                    .cpu()
                ),

                float(
                    comp["lambda"]
                    .detach()
                    .cpu()
                ),

                float(
                    comp[
                        "mass_norm_integral"
                    ]
                    .detach()
                    .cpu()
                ),

                float(
                    comp[
                        "residual_rms"
                    ]
                    .detach()
                    .cpu()
                ),

                float(
                    comp[
                        "relative_residual_rms"
                    ]
                    .detach()
                    .cpu()
                ),

                lr_nn_now,
                lr_lambda_now,
            )

        # Adam snapshots
        if (
            cfg.save_epoch_plots
            and cfg.plot_every > 0
            and (
                epoch_number == 1
                or (
                    epoch_number
                    % cfg.plot_every
                    == 0
                )
                or (
                    epoch_number
                    == cfg.adam_epochs
                )
            )
        ):
            plot_snapshot(
                model=model,

                X_test=X_test,

                history=history,

                optimization_step=(
                    optimization_step
                ),

                output_path=(
                    plot_dir
                    / (
                        f"step_"
                        f"{optimization_step:06d}"
                        f".png"
                    )
                ),

                reference_x=(
                    snapshot_reference_x
                ),

                reference_phi=(
                    snapshot_reference_phi
                ),

                reference_lambda=(
                    snapshot_reference_lambda
                ),
            )

            # plot_snapshot/predict switches model to eval mode.
            model.train()

            gc.collect()

        # Adam backpropagation
        total_loss.backward()

        # Gradient validity check
        for (
            name,
            parameter,
        ) in model.named_parameters():

            if parameter.grad is None:
                continue

            if not torch.isfinite(
                parameter.grad
            ).all().item():
                raise FloatingPointError(
                    "Non-finite gradient detected "
                    "for parameter "
                    f"'{name}' at Adam epoch "
                    f"{epoch_number}."
                )

        # Optional gradient clipping — Adam only
        if (
            cfg.grad_clip_norm
            is not None
        ):
            torch.nn.utils.clip_grad_norm_(
                model.nn_phi.parameters(),
                cfg.grad_clip_norm,
            )

            torch.nn.utils.clip_grad_norm_(
                [
                    model.lambda_raw
                ],
                cfg.grad_clip_norm,
            )

        # Adam parameter updates
        optimizer_nn.step()

        optimizer_lambda.step()

        scheduler_nn.step()

        scheduler_lambda.step()

        del total_loss
        del comp

    # Exact POST-update Adam handoff state
    # This is the state from which L-BFGS begins.
    model.train()

    (
        adam_handoff_total,
        adam_handoff_comp,
    ) = compute_loss(
        model,
        X_colloc,
        X_quad,
        W_quad,
        cfg,
        device,
    )

    adam_handoff_loss = float(
        adam_handoff_total
        .detach()
        .cpu()
    )

    if not math.isfinite(
        adam_handoff_loss
    ):
        raise FloatingPointError(
            "Non-finite physics-informed loss "
            "at the Adam-to-L-BFGS handoff."
        )

    # The post-update handoff state is also a legitimate global-best candidate.
    maybe_update_best(
        current_loss=(
            adam_handoff_loss
        ),

        optimization_step=(
            cfg.adam_epochs
        ),

        optimizer_phase="Adam",

        phase_step=(
            cfg.adam_epochs
        ),

        checkpoint_state=(
            "adam_post_update_handoff"
        ),

        optimizer_nn=(
            optimizer_nn
        ),

        optimizer_lambda=(
            optimizer_lambda
        ),

        scheduler_nn=(
            scheduler_nn
        ),

        scheduler_lambda=(
            scheduler_lambda
        ),

        optimizer_lbfgs=None,
    )

    torch.save(
        cpu_state_dict(
            model
        ),
        output_dir
        / "adam_handoff_state_dict.pt",
    )

    LOGGER.info(
        "Adam handoff state: "
        "total=%.6e | "
        "lambda=%.9f | "
        "R_rel=%.3e",

        adam_handoff_loss,

        float(
            adam_handoff_comp[
                "lambda"
            ]
            .detach()
            .cpu()
        ),

        float(
            adam_handoff_comp[
                "relative_residual_rms"
            ]
            .detach()
            .cpu()
        ),
    )

    del adam_handoff_total
    del adam_handoff_comp

    gc.collect()

    # Stage II — deterministic full-batch L-BFGS
    lbfgs_params = [
        parameter
        for parameter
        in model.parameters()
        if parameter.requires_grad
    ]

    if not lbfgs_params:
        raise RuntimeError(
            "No trainable parameters are "
            "available for L-BFGS."
        )

    initial_block = min(
        cfg.lbfgs_block_iter,
        cfg.lbfgs_max_iter,
    )

    optimizer_lbfgs = (
        torch.optim.LBFGS(
            lbfgs_params,

            lr=(
                cfg.lbfgs_lr
            ),

            max_iter=(
                initial_block
            ),

            # Use a generous function-evaluation allowance so that
            # premature termination is not caused merely by the
            # line-search evaluation cap.
            max_eval=max(
                25,
                5
                * initial_block,
            ),

            tolerance_grad=(
                cfg.lbfgs_tolerance_grad
            ),

            tolerance_change=(
                cfg.lbfgs_tolerance_change
            ),

            history_size=(
                cfg.lbfgs_history_size
            ),

            line_search_fn=(
                cfg.lbfgs_line_search_fn
            ),
        )
    )

    LOGGER.info(
        "Starting L-BFGS: "
        "lr=%.6g | "
        "max_iter=%d | "
        "block_iter=%d | "
        "history_size=%d | "
        "tol_grad=%.3e | "
        "tol_change=%.3e | "
        "line_search=%s",

        cfg.lbfgs_lr,
        cfg.lbfgs_max_iter,
        cfg.lbfgs_block_iter,
        cfg.lbfgs_history_size,
        cfg.lbfgs_tolerance_grad,
        cfg.lbfgs_tolerance_change,
        cfg.lbfgs_line_search_fn,
    )

    first_lbfgs_param = (
        lbfgs_params[0]
    )

    lbfgs_iter = 0

    lbfgs_func_evals = 0

    # L-BFGS block loop
    while (
        lbfgs_iter
        < cfg.lbfgs_max_iter
    ):

        remaining = (
            cfg.lbfgs_max_iter
            - lbfgs_iter
        )

        requested_block = min(
            cfg.lbfgs_block_iter,
            remaining,
        )

        # Adapt the final block if the total L-BFGS budget is not exactly
        # divisible by lbfgs_block_iter.
        optimizer_lbfgs.param_groups[
            0
        ]["max_iter"] = int(
            requested_block
        )

        optimizer_lbfgs.param_groups[
            0
        ]["max_eval"] = max(
            25,
            5
            * int(
                requested_block
            ),
        )

        state_before = (
            optimizer_lbfgs.state[
                first_lbfgs_param
            ]
        )

        n_iter_before = int(
            state_before.get(
                "n_iter",
                0,
            )
        )

        func_evals_before = int(
            state_before.get(
                "func_evals",
                0,
            )
        )

        # L-BFGS deterministic closure
        def closure() -> torch.Tensor:

            optimizer_lbfgs.zero_grad(
                set_to_none=True
            )

            model.train()

            loss, _ = compute_loss(
                model,
                X_colloc,
                X_quad,
                W_quad,
                cfg,
                device,
            )

            loss_value = float(
                loss
                .detach()
                .cpu()
            )

            if not math.isfinite(
                loss_value
            ):
                raise FloatingPointError(
                    "Non-finite total loss "
                    "inside the L-BFGS closure."
                )

            loss.backward()

            # IMPORTANT:
            # Gradient clipping is intentionally NOT applied in L-BFGS.
            # The quasi-Newton update and strong-Wolfe line search use the
            # actual objective gradient.
            for (
                name,
                parameter,
            ) in model.named_parameters():

                if parameter.grad is None:
                    continue

                if not torch.isfinite(
                    parameter.grad
                ).all().item():
                    raise FloatingPointError(
                        "Non-finite gradient "
                        "detected for parameter "
                        f"'{name}' inside "
                        "the L-BFGS closure."
                    )

            return loss

        # Execute one L-BFGS block
        optimizer_lbfgs.step(
            closure
        )

        state_after = (
            optimizer_lbfgs.state[
                first_lbfgs_param
            ]
        )

        n_iter_after = int(
            state_after.get(
                "n_iter",
                n_iter_before,
            )
        )

        func_evals_after = int(
            state_after.get(
                "func_evals",
                func_evals_before,
            )
        )

        performed_iter = (
            n_iter_after
            - n_iter_before
        )

        performed_evals = (
            func_evals_after
            - func_evals_before
        )

        # n_iter and func_evals are cumulative in the persistent L-BFGS state.
        lbfgs_iter = (
            n_iter_after
        )

        lbfgs_func_evals = (
            func_evals_after
        )

        # Accepted block-end state
        # We deliberately do NOT store transient strong-Wolfe trial points.
        model.train()

        (
            accepted_total,
            accepted_comp,
        ) = compute_loss(
            model,
            X_colloc,
            X_quad,
            W_quad,
            cfg,
            device,
        )

        accepted_loss = float(
            accepted_total
            .detach()
            .cpu()
        )

        if not math.isfinite(
            accepted_loss
        ):
            raise FloatingPointError(
                "Non-finite accepted-state loss "
                "after an L-BFGS block."
            )

        optimization_step = (
            cfg.adam_epochs
            + lbfgs_iter
        )

        # L-BFGS history
        append_history(
            history=history,

            comp=(
                accepted_comp
            ),

            optimization_step=(
                optimization_step
            ),

            optimizer_phase=(
                "L-BFGS"
            ),

            phase_step=(
                lbfgs_iter
            ),

            lr_nn=math.nan,

            lr_lambda=math.nan,

            lr_lbfgs=float(
                optimizer_lbfgs
                .param_groups[0]["lr"]
            ),

            lbfgs_func_evals=(
                lbfgs_func_evals
            ),
        )

        # Global best checkpoint
        maybe_update_best(
            current_loss=(
                accepted_loss
            ),

            optimization_step=(
                optimization_step
            ),

            optimizer_phase=(
                "L-BFGS"
            ),

            phase_step=(
                lbfgs_iter
            ),

            checkpoint_state=(
                "lbfgs_accepted_block_endpoint"
            ),

            optimizer_nn=None,
            optimizer_lambda=None,

            scheduler_nn=None,
            scheduler_lambda=None,

            optimizer_lbfgs=(
                optimizer_lbfgs
            ),
        )

        # L-BFGS logging
        # Because history is stored only at accepted block endpoints,
        # each completed block is logged.
        LOGGER.info(
            "[L-BFGS] "
            "iter %d/%d | "
            "global_step=%d | "
            "block_iter=%d | "
            "block_evals=%d | "
            "total_evals=%d | "
            "total=%.6e | "
            "DE=%.6e | "
            "BC=%.6e | "
            "lambda=%.9f | "
            "int(r*phi^2)=%.8f | "
            "R_rms=%.3e | "
            "R_rel=%.3e",

            lbfgs_iter,
            cfg.lbfgs_max_iter,

            optimization_step,

            performed_iter,
            performed_evals,
            lbfgs_func_evals,

            accepted_loss,

            float(
                accepted_comp[
                    "de"
                ]
                .detach()
                .cpu()
            ),

            float(
                accepted_comp[
                    "bc"
                ]
                .detach()
                .cpu()
            ),

            float(
                accepted_comp[
                    "lambda"
                ]
                .detach()
                .cpu()
            ),

            float(
                accepted_comp[
                    "mass_norm_integral"
                ]
                .detach()
                .cpu()
            ),

            float(
                accepted_comp[
                    "residual_rms"
                ]
                .detach()
                .cpu()
            ),

            float(
                accepted_comp[
                    "relative_residual_rms"
                ]
                .detach()
                .cpu()
            ),
        )

        # L-BFGS snapshots
        # A snapshot is generated whenever a plot_every boundary is crossed,
        # at the final budget, or at an internally terminated final block.
        crossed_plot_boundary = (
            cfg.save_epoch_plots
            and cfg.plot_every > 0
            and (
                (
                    lbfgs_iter
                    // cfg.plot_every
                )
                >
                (
                    n_iter_before
                    // cfg.plot_every
                )
                or (
                    lbfgs_iter
                    >= cfg.lbfgs_max_iter
                )
                or (
                    performed_iter
                    < requested_block
                )
            )
        )

        if crossed_plot_boundary:

            plot_snapshot(
                model=model,

                X_test=X_test,

                history=history,

                optimization_step=(
                    optimization_step
                ),

                output_path=(
                    plot_dir
                    / (
                        f"step_"
                        f"{optimization_step:06d}"
                        f".png"
                    )
                ),

                reference_x=(
                    snapshot_reference_x
                ),

                reference_phi=(
                    snapshot_reference_phi
                ),

                reference_lambda=(
                    snapshot_reference_lambda
                ),
            )

            model.train()

            gc.collect()

        del accepted_total
        del accepted_comp

        gc.collect()

        # L-BFGS convergence / no-progress detection
        # Since max_eval was deliberately made generous, early termination
        # before requested_block is interpreted as an internal L-BFGS stopping
        # condition rather than merely the default function-evaluation limit.
        if performed_iter <= 0:

            LOGGER.info(
                "L-BFGS stopped early: "
                "no additional quasi-Newton "
                "iteration was accepted."
            )

            break

        if (
            performed_iter
            < requested_block
        ):

            LOGGER.info(
                "L-BFGS stopped early after "
                "%d iterations; the internal "
                "stopping criterion terminated "
                "the current block after %d "
                "of %d requested iterations.",

                lbfgs_iter,
                performed_iter,
                requested_block,
            )

            break

    # Restore globally best physics-informed state across BOTH stages
    if (
        best[
            "model_state"
        ]
        is None
    ):
        raise RuntimeError(
            "No finite best model state "
            "was recorded."
        )

    model.load_state_dict(
        best[
            "model_state"
        ]
    )

    model.to(
        device
    )

    model.train()

    (
        best_total_tensor,
        best_comp_tensor,
    ) = compute_loss(
        model,
        X_colloc,
        X_quad,
        W_quad,
        cfg,
        device,
    )

    best_total_value = float(
        best_total_tensor
        .detach()
        .cpu()
    )

    best_comp = {
        key: float(
            value
            .detach()
            .cpu()
        )
        for (
            key,
            value,
        )
        in best_comp_tensor.items()
    }

    if not math.isclose(
        best_total_value,
        float(
            best[
                "loss"
            ]
        ),
        rel_tol=1.0e-9,
        abs_tol=1.0e-12,
    ):
        LOGGER.warning(
            "Restored best-loss check differs "
            "from recorded value: "
            "recorded=%.12e, recomputed=%.12e",

            float(
                best[
                    "loss"
                ]
            ),

            best_total_value,
        )

    best_step = int(
        best[
            "optimization_step"
        ]
    )

    best_phase = str(
        best[
            "optimizer_phase"
        ]
    )

    best_phase_step = int(
        best[
            "phase_step"
        ]
    )

    del best_total_tensor
    del best_comp_tensor

    gc.collect()

    # Best eigenvalue and physical frequency
    best_lambda = float(
        model.lambda_
        .detach()
        .cpu()
    )

    omega = lambda_to_omega(
        best_lambda,
        cfg,
    )

    frequency_hz = (
        lambda_to_frequency_hz(
            best_lambda,
            cfg,
        )
    )

    LOGGER.info(
        "Training complete."
    )

    LOGGER.info(
        "Best optimization step: %d | "
        "phase=%s | "
        "phase_step=%d",

        best_step,
        best_phase,
        best_phase_step,
    )

    LOGGER.info(
        "Best total loss: %.12e",
        best_total_value,
    )

    LOGGER.info(
        "Best lambda: %.12f",
        best_lambda,
    )

    LOGGER.info(
        "Physical omega: %.12e rad/s",
        omega,
    )

    LOGGER.info(
        "Physical frequency: %.12e Hz",
        frequency_hz,
    )

    LOGGER.info(
        "Best hard clamped-end residuals: "
        "Phi(0)=%.3e, "
        "Phi'(0)=%.3e, "
        "Phi''(0)=%.3e",

        best_comp[
            "phi_0"
        ],

        best_comp[
            "dphi_0"
        ],

        best_comp[
            "ddphi_0"
        ],
    )

    LOGGER.info(
        "Best active free-end residuals: "
        "Phi''(1)=%.3e, "
        "Mbar(1)=%.3e, "
        "Mbar'(1)=%.3e",

        best_comp[
            "ddphi_1"
        ],

        best_comp[
            "moment_1"
        ],

        best_comp[
            "shear_1"
        ],
    )

    # Save synchronized globally best model/checkpoint
    torch.save(
        cpu_state_dict(
            model
        ),

        output_dir
        / "best_state_dict.pt",
    )

    torch.save(
        {
            "best_optimization_step": (
                best_step
            ),

            "best_optimizer_phase": (
                best_phase
            ),

            "best_phase_step": (
                best_phase_step
            ),

            "best_loss": (
                best_total_value
            ),

            "lambda": (
                best_lambda
            ),

            "omega_rad_s": (
                omega
            ),

            "frequency_hz": (
                frequency_hz
            ),

            "model_state_dict": (
                cpu_state_dict(
                    model
                )
            ),

            "optimizer_nn_state_dict_at_best": (
                best[
                    "optimizer_nn_state"
                ]
            ),

            "optimizer_lambda_state_dict_at_best": (
                best[
                    "optimizer_lambda_state"
                ]
            ),

            "scheduler_nn_state_dict_at_best": (
                best[
                    "scheduler_nn_state"
                ]
            ),

            "scheduler_lambda_state_dict_at_best": (
                best[
                    "scheduler_lambda_state"
                ]
            ),

            "optimizer_lbfgs_state_dict_at_best": (
                best[
                    "optimizer_lbfgs_state"
                ]
            ),

            "checkpoint_state": str(
                best[
                    "checkpoint_state"
                ]
            ),

            "adam_epochs_completed": int(
                cfg.adam_epochs
            ),

            "lbfgs_iterations_completed": int(
                lbfgs_iter
            ),

            "lbfgs_function_evaluations": int(
                lbfgs_func_evals
            ),

            "config": (
                config_dict
            ),

            "reference_used_in_training": False,
        },

        output_dir
        / "best_full.pt",
    )

    # Save training history
    save_history_csv(
        history,
        output_dir,
    )

    # Final PINN post-processing
    model.eval()

    X_np = (
        X_test
        .detach()
        .cpu()
        .numpy()
        .reshape(-1)
    )

    X_quad_np = (
        X_quad
        .detach()
        .cpu()
        .numpy()
        .reshape(-1)
    )

    W_quad_np = (
        W_quad
        .detach()
        .cpu()
        .numpy()
        .reshape(-1)
    )

    sec_test = section_resultants_numpy(
        X_np,
        cfg,
    )

    r_test = (
        sec_test[
            "r"
        ]
    )

    # Raw PINN eigenfunction
    phi_pinn_raw = predict(
        model,
        X_test,
    )

    pinn_mass_norm_quad = float(
        best_comp[
            "raw_mass_norm_integral"
        ]
    )

    if (
        not math.isfinite(
            pinn_mass_norm_quad
        )
        or (
            pinn_mass_norm_quad
            <= 1.0e-300
        )
    ):
        raise RuntimeError(
            "Invalid PINN mass-normalization "
            "integral during post-processing."
        )

    # Explicitly mass-normalized exported mode.
    phi_pinn = (
        phi_pinn_raw
        / math.sqrt(
            pinn_mass_norm_quad
        )
    )

    pinn_mass_norm_test = float(
        np.trapezoid(
            r_test
            * phi_pinn**2,

            X_np,
        )
    )

    phi_pinn_plot = (
        maxabs_normalize_mode(
            phi_pinn
        )
    )

    pd.DataFrame(
        {
            "X": X_np,

            "Phi_PINN_raw": (
                phi_pinn_raw
            ),

            "Phi_PINN_mass_normalized": (
                phi_pinn
            ),

            "Phi_PINN_maxabs_normalized": (
                phi_pinn_plot
            ),

            "d": (
                sec_test[
                    "d"
                ]
            ),

            "r": (
                sec_test[
                    "r"
                ]
            ),
        }
    ).to_csv(
        output_dir
        / "best_pinn_eigenfunction.csv",

        index=False,
    )

    # Independent BVP validation
    # The reference is still entirely external to training.
    if (
        snapshot_reference
        is not None
    ):
        ref = (
            snapshot_reference
        )

    else:
        ref = solve_reference_bvp_cf(
            cfg
        )

    validation = {
        "best_optimization_step": int(
            best_step
        ),

        "best_optimizer_phase": str(
            best_phase
        ),

        "best_phase_step": int(
            best_phase_step
        ),

        "adam_epochs_completed": int(
            cfg.adam_epochs
        ),

        "lbfgs_iterations_completed": int(
            lbfgs_iter
        ),

        "lbfgs_function_evaluations": int(
            lbfgs_func_evals
        ),

        "best_total_loss": float(
            best_total_value
        ),

        "lambda_pinn": float(
            best_lambda
        ),

        "omega_pinn_rad_s": float(
            omega
        ),

        "frequency_pinn_hz": float(
            frequency_hz
        ),

        "normalized_mass_integral": float(
            best_comp[
                "mass_norm_integral"
            ]
        ),

        "raw_pinn_mass_integral": float(
            best_comp[
                "raw_mass_norm_integral"
            ]
        ),

        "pinn_mass_norm_integral_postprocessed": float(
            pinn_mass_norm_test
        ),

        "pde_residual_rms": float(
            best_comp[
                "residual_rms"
            ]
        ),

        "operator_scale_rms": float(
            best_comp[
                "operator_scale_rms"
            ]
        ),

        "relative_pde_residual_rms": float(
            best_comp[
                "relative_residual_rms"
            ]
        ),

        "max_abs_pde_residual": float(
            best_comp[
                "max_abs_residual"
            ]
        ),

        # Hard clamped-end diagnostics
        "clamped_phi_0": float(
            best_comp[
                "phi_0"
            ]
        ),

        "clamped_dphi_0": float(
            best_comp[
                "dphi_0"
            ]
        ),

        "clamped_ddphi_0": float(
            best_comp[
                "ddphi_0"
            ]
        ),

        # Active free-end diagnostics
        "free_ddphi_1": float(
            best_comp[
                "ddphi_1"
            ]
        ),

        "free_moment_1": float(
            best_comp[
                "moment_1"
            ]
        ),

        "free_shear_1": float(
            best_comp[
                "shear_1"
            ]
        ),

        "reference_used_in_training": False,
    }

    # BVP reference available
    if ref is not None:

        sol = ref[
            "solution"
        ]

        lambda_ref = float(
            ref[
                "lambda"
            ]
        )

        # BVP mass normalization using the same Gauss-Legendre rule
        phi_ref_quad_raw = (
            sol.sol(
                X_quad_np
            )[0]
        )

        r_quad_np = (
            section_resultants_numpy(
                X_quad_np,
                cfg,
            )[
                "r"
            ]
        )

        ref_mass_norm_quad = float(
            np.sum(
                W_quad_np
                * r_quad_np
                * phi_ref_quad_raw**2
            )
        )

        if (
            not math.isfinite(
                ref_mass_norm_quad
            )
            or (
                ref_mass_norm_quad
                <= 1.0e-300
            )
        ):
            raise RuntimeError(
                "Invalid BVP mass-normalization integral."
            )

        phi_ref_raw = (
            sol.sol(
                X_np
            )[0]
        )

        phi_ref = (
            phi_ref_raw
            / math.sqrt(
                ref_mass_norm_quad
            )
        )

        # Resolve arbitrary reference-mode sign
        inner = float(
            np.trapezoid(
                r_test
                * phi_pinn
                * phi_ref,

                X_np,
            )
        )

        reference_sign = (
            1.0
        )

        if inner < 0.0:

            reference_sign = (
                -1.0
            )

            phi_ref = (
                -phi_ref
            )

        phi_ref_raw_aligned = (
            reference_sign
            * phi_ref_raw
        )

        # Mode-shape metrics
        metrics = weighted_mode_metrics(
            X_np,
            phi_pinn,
            phi_ref,
            cfg,
        )

        # Eigenvalue and frequency errors
        lambda_rel_err = (
            abs(
                best_lambda
                - lambda_ref
            )
            / lambda_ref
        )

        omega_ref = (
            lambda_to_omega(
                lambda_ref,
                cfg,
            )
        )

        frequency_ref_hz = (
            lambda_to_frequency_hz(
                lambda_ref,
                cfg,
            )
        )

        frequency_rel_err = (
            abs(
                frequency_hz
                - frequency_ref_hz
            )
            / frequency_ref_hz
        )

        ref_mass_norm_test = float(
            np.trapezoid(
                r_test
                * phi_ref**2,

                X_np,
            )
        )

        validation.update(
            {
                "lambda_reference_bvp": float(
                    lambda_ref
                ),

                "lambda_relative_error": float(
                    lambda_rel_err
                ),

                "lambda_relative_error_percent": float(
                    100.0
                    * lambda_rel_err
                ),

                "omega_reference_bvp_rad_s": float(
                    omega_ref
                ),

                "frequency_reference_bvp_hz": float(
                    frequency_ref_hz
                ),

                "frequency_relative_error": float(
                    frequency_rel_err
                ),

                "frequency_relative_error_percent": float(
                    100.0
                    * frequency_rel_err
                ),

                **metrics,

                "reference_bvp_max_rms_residual": float(
                    np.max(
                        sol.rms_residuals
                    )
                ),

                "reference_bvp_mesh_nodes": int(
                    sol.x.size
                ),

                "reference_bvp_raw_mass_norm_gauss": float(
                    ref_mass_norm_quad
                ),

                "reference_bvp_mass_norm_postprocessed": float(
                    ref_mass_norm_test
                ),
            }
        )

        # BVP metadata
        if "mode_number" in ref:

            validation[
                "reference_bvp_mode_number_candidate"
            ] = int(
                ref[
                    "mode_number"
                ]
            )

        if "interior_nodes" in ref:

            validation[
                "reference_bvp_interior_nodes"
            ] = int(
                ref[
                    "interior_nodes"
                ]
            )

            validation[
                "reference_bvp_zero_node_fundamental_candidate"
            ] = bool(
                ref[
                    "interior_nodes"
                ]
                == 0
            )

        if "initial_guess" in ref:

            validation[
                "reference_bvp_initial_lambda_guess"
            ] = float(
                ref[
                    "initial_guess"
                ]
            )

        if (
            "mass_norm_integral"
            in ref
        ):

            validation[
                "reference_bvp_solver_mass_norm_integral"
            ] = float(
                ref[
                    "mass_norm_integral"
                ]
            )

        LOGGER.info(
            "Post-training validation: "
            "lambda_ref=%.12f | "
            "lambda err=%.6f%% | "
            "MAC=%.10f | "
            "mode rel.L2=%.6e | "
            "frequency err=%.6f%%",

            lambda_ref,

            100.0
            * lambda_rel_err,

            metrics[
                "mass_weighted_MAC"
            ],

            metrics[
                "relative_L2_mode_error"
            ],

            100.0
            * frequency_rel_err,
        )

        # Consistent visualization orientation
        pinn_plot_scale = float(
            np.max(
                np.abs(
                    phi_pinn
                )
            )
        )

        ref_plot_scale = float(
            np.max(
                np.abs(
                    phi_ref
                )
            )
        )

        if (
            pinn_plot_scale
            <= 1.0e-14
            or
            ref_plot_scale
            <= 1.0e-14
        ):
            raise RuntimeError(
                "Near-zero mode amplitude "
                "encountered during comparison plotting."
            )

        anchor_idx = int(
            np.argmax(
                np.abs(
                    phi_pinn
                )
            )
        )

        common_plot_sign = (
            -1.0
            if (
                phi_pinn[
                    anchor_idx
                ]
                < 0.0
            )
            else 1.0
        )

        phi_pinn_plot_compare = (
            common_plot_sign
            * phi_pinn
            / pinn_plot_scale
        )

        phi_ref_plot = (
            common_plot_sign
            * phi_ref
            / ref_plot_scale
        )

        # Save PINN-vs-BVP eigenfunctions
        pd.DataFrame(
            {
                "X": X_np,

                "Phi_PINN_raw": (
                    phi_pinn_raw
                ),

                "Phi_BVP_raw_sign_aligned": (
                    phi_ref_raw_aligned
                ),

                "Phi_PINN_mass_normalized": (
                    phi_pinn
                ),

                "Phi_BVP_mass_normalized": (
                    phi_ref
                ),

                "Phi_PINN_maxabs_normalized": (
                    phi_pinn_plot_compare
                ),

                "Phi_BVP_maxabs_normalized": (
                    phi_ref_plot
                ),
            }
        ).to_csv(
            output_dir
            / "pinn_vs_bvp_eigenfunction.csv",

            index=False,
        )

        # Final publication-style comparison
        plot_final_mode_comparison(
            X=X_np,

            phi_pinn=(
                phi_pinn
            ),

            lambda_pinn=(
                best_lambda
            ),

            optimization_step=(
                best_step
            ),

            output_path=(
                output_dir
                / "best_eigenfunction_vs_bvp.png"
            ),

            phi_ref=(
                phi_ref
            ),

            lambda_ref=(
                lambda_ref
            ),
        )

    # No BVP reference available
    else:

        plot_final_mode_comparison(
            X=X_np,

            phi_pinn=(
                phi_pinn
            ),

            lambda_pinn=(
                best_lambda
            ),

            optimization_step=(
                best_step
            ),

            output_path=(
                output_dir
                / "best_eigenfunction.png"
            ),

            phi_ref=None,

            lambda_ref=None,
        )

    # Save validation summary
    with open(
        output_dir
        / "validation_summary.json",

        "w",

        encoding="utf-8",
    ) as f:

        json.dump(
            validation,
            f,
            indent=2,
        )

    # Save best optimization-state metadata
    with open(
        output_dir
        / "best_optimization_step.json",

        "w",

        encoding="utf-8",
    ) as f:

        json.dump(
            {
                "best_optimization_step": int(
                    best_step
                ),

                "best_optimizer_phase": str(
                    best_phase
                ),

                "best_phase_step": int(
                    best_phase_step
                ),
            },

            f,

            indent=2,
        )

    # Return results to Jupyter / Python
    return {
        "model": model,

        "history": history,

        "best_optimization_step": int(
            best_step
        ),

        "best_optimizer_phase": str(
            best_phase
        ),

        "best_phase_step": int(
            best_phase_step
        ),

        "adam_epochs_completed": int(
            cfg.adam_epochs
        ),

        "lbfgs_iterations_completed": int(
            lbfgs_iter
        ),

        "lbfgs_function_evaluations": int(
            lbfgs_func_evals
        ),

        "best_loss": float(
            best_total_value
        ),

        "best_lambda": float(
            best_lambda
        ),

        "omega_rad_s": float(
            omega
        ),

        "frequency_hz": float(
            frequency_hz
        ),

        "validation": validation,

        "device": str(
            device
        ),
    }

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# 🔎 Main

# %%
# Jupyter Notebook configuration and execution

cfg = Config(
    # 2D-FG material gradation
    k=1.0,
    beta=1.0,

    # NSGT
    tau=0.05,
    zeta=0.05,

    # Geometry
    L_over_h=30.0,

    # PINN discretization
    n_colloc=128,
    n_quad=128,
    n_test=401,

    x_min=0.0,
    x_max=1.0,

    # Neural network
    hidden_1=128,
    hidden_2=64,
    hidden_3=32,
    use_bias=True,

    # Hybrid optimization
    # Phase I  : Adam for 20,000 epochs.
    # Phase II : full-batch L-BFGS refinement for up to 10,000
    #            quasi-Newton iterations.
    #

    # Phase I: Adam
    adam_epochs=20_000,

    lr_nn=2.0e-3,
    lr_lambda=1.0e-3,

    lambda_init=100.0,

    lr_milestones=(
        3_000,
        4_250,
        15_000,
    ),

    lr_gamma=0.20,

    # Phase II: L-BFGS
    lbfgs_max_iter=10_000,
    lbfgs_block_iter=100,

    lbfgs_lr=1.0,
    lbfgs_history_size=100,

    lbfgs_tolerance_grad=1.0e-9,
    lbfgs_tolerance_change=1.0e-12,

    lbfgs_line_search_fn="strong_wolfe",

    # Physics-informed objective
    alpha_de=1.0,
    alpha_bc=10.0,
    alpha_norm=0.0,

    l2_coeff=1.0e-6,
    apply_l2=False,

    grad_clip_norm=None,

    # Reproducibility
    seed=42,
    deterministic_torch=True,

    # Output
    log_every=100,
    plot_every=500,
    save_epoch_plots=True,

    output_dir=(
        "results_2dfg_eb_nsgt_cf_"
        "adam20k_lbfgs10k_alphaBC10_seed42"
    ),

    device="auto",

    # Independent C-F BVP validation
    run_reference_bvp=True,
    reference_lambda_guess=10.0,
    reference_tol=1.0e-7,
    reference_max_nodes=20_000,
)


# Run training

results = train(cfg)


# Compact final summary

print("\n" + "=" * 78)
print("FINAL HYBRID PINN RESULTS")
print("=" * 78)

print(f"Device                  : {results['device']}")

print(
    f"Best optimization step  : "
    f"{results['best_optimization_step']}"
)

print(
    f"Best optimizer phase     : "
    f"{results['best_optimizer_phase']}"
)

print(
    f"Best phase step          : "
    f"{results['best_phase_step']}"
)

print(
    f"Adam epochs completed    : "
    f"{results['adam_epochs_completed']}"
)

print(
    f"L-BFGS iterations        : "
    f"{results['lbfgs_iterations_completed']}"
)

print(
    f"L-BFGS function evals    : "
    f"{results['lbfgs_function_evaluations']}"
)

print(f"Best loss                : {results['best_loss']:.12e}")
print(f"Best lambda              : {results['best_lambda']:.12f}")
print(f"Omega [rad/s]            : {results['omega_rad_s']:.12e}")
print(f"Frequency [Hz]           : {results['frequency_hz']:.12e}")

validation = results.get(
    "validation",
    {},
)

if "lambda_reference_bvp" in validation:
    print("-" * 78)
    print("Independent BVP validation")

    print(
        f"Reference lambda         : "
        f"{validation['lambda_reference_bvp']:.12f}"
    )

    print(
        f"Lambda error [%]         : "
        f"{validation['lambda_relative_error_percent']:.6f}"
    )

    print(
        f"Mass-weighted MAC        : "
        f"{validation['mass_weighted_MAC']:.10f}"
    )

    print(
        f"Mode rel. L2             : "
        f"{validation['relative_L2_mode_error']:.6e}"
    )

    if "frequency_relative_error_percent" in validation:
        print(
            f"Frequency error [%]      : "
            f"{validation['frequency_relative_error_percent']:.6f}"
        )

    if "reference_bvp_interior_nodes" in validation:
        print(
            f"BVP interior nodes       : "
            f"{validation['reference_bvp_interior_nodes']}"
        )

print("-" * 78)

print(
    f"Relative PDE residual RMS: "
    f"{validation['relative_pde_residual_rms']:.6e}"
)

print(
    f"Hard clamp residuals     : "
    f"Phi(0)={validation['clamped_phi_0']:.3e}, "
    f"Phi'(0)={validation['clamped_dphi_0']:.3e}, "
    f"Phi''(0)={validation['clamped_ddphi_0']:.3e}"
)

print(
    f"Free-end residuals       : "
    f"Phi''(1)={validation['free_ddphi_1']:.3e}, "
    f"Mbar(1)={validation['free_moment_1']:.3e}, "
    f"Mbar'(1)={validation['free_shear_1']:.3e}"
)

print(
    f"Normalized mass integral : "
    f"{validation['normalized_mass_integral']:.12f}"
)

print("=" * 78)
# Out:
# 2026-09-06 15:12:37,571 - INFO - Using device: cpu
# 2026-09-06 15:12:37,571 - INFO - Default dtype: torch.float64
# 2026-09-06 15:12:37,571 - INFO - Model: Reduced Flexural 2D-FG Euler-Bernoulli-NSGT, C-F (cantilever) fixed-curvature BC
# 2026-09-06 15:12:37,571 - INFO - k=1, beta=1, tau=0.05, zeta=0.05, L/h=30
# 2026-09-06 15:12:37,571 - INFO - Optimization protocol: Adam=20000 epochs -> L-BFGS<=10000 quasi-Newton iterations
# 2026-09-06 15:12:37,586 - INFO - Closed-form section-resultant check: max relative error = 9.944e-16
# 2026-09-06 15:12:37,587 - INFO - Coefficient ranges: d(X)=[0.746154, 1], r(X)=[1, 1.48485]
# 2026-09-06 15:12:37,588 - INFO - Max |z_E|/h = 0.05, max |z_rho|/h = 0.0544218; I1^rho is nonzero in general.
# 2026-09-06 15:12:37,620 - INFO - Compact-vs-expanded operator check: max abs=1.421e-14, relative=3.199e-16
# 2026-09-06 15:12:38,681 - INFO - BVP candidate: guess=5 | lambda=10.255824087315 | interior_nodes=0 | mesh_nodes=967 | max_rms=9.972e-08
# 2026-09-06 15:12:38,743 - INFO - BVP candidate: guess=10 | lambda=10.255824087315 | interior_nodes=0 | mesh_nodes=967 | max_rms=9.972e-08
# 2026-09-06 15:12:38,806 - INFO - BVP candidate: guess=20 | lambda=10.255824087276 | interior_nodes=0 | mesh_nodes=1002 | max_rms=9.972e-08
# 2026-09-06 15:12:38,808 - INFO - Independent first-mode BVP validation converged: lambda_ref=10.255824087276 | interior_nodes=0 | mesh_nodes=1002 | max_rms=9.972e-08 | mass_norm=1.000000308500
# 2026-09-06 15:12:38,809 - INFO - Live C-F snapshot reference prepared: lambda_BVP = 10.255824087
# 2026-09-06 15:12:38,811 - INFO - Trainable NN parameters: 10625
# 2026-09-06 15:12:38,811 - INFO - Total trainable parameters including lambda_raw: 10626
# 2026-09-06 15:12:38,812 - INFO - No reference eigenvalue/eigenfunction is used during optimization.
# 2026-09-06 15:12:40,305 - INFO - Adam LR milestones: [3000, 4250, 15000]; gamma=0.2
# 2026-09-06 15:12:40,511 - INFO - [Adam] epoch 1/20000 | total=2.314764e+04 | DE=1.193722e+04 | BC=1.121042e+04 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=100.000000000 | int(r*phi^2)=1.00000000 | R_rms=1.093e+02 | R_rel=7.102e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:12:40,770 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:12:41,177 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:13:25,614 - INFO - [Adam] epoch 100/20000 | total=9.060003e+03 | DE=6.812544e+03 | BC=2.247459e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=91.767010366 | int(r*phi^2)=1.00000000 | R_rms=8.254e+01 | R_rel=5.062e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:14:07,363 - INFO - [Adam] epoch 200/20000 | total=6.920750e+03 | DE=4.931834e+03 | BC=1.988917e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=85.617326914 | int(r*phi^2)=1.00000000 | R_rms=7.023e+01 | R_rel=4.319e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:14:50,113 - INFO - [Adam] epoch 300/20000 | total=6.198668e+03 | DE=4.438708e+03 | BC=1.759960e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=80.089779614 | int(r*phi^2)=1.00000000 | R_rms=6.662e+01 | R_rel=4.349e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:15:32,828 - INFO - [Adam] epoch 400/20000 | total=5.582503e+03 | DE=4.000281e+03 | BC=1.582222e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=75.008697886 | int(r*phi^2)=1.00000000 | R_rms=6.325e+01 | R_rel=4.384e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:16:14,777 - INFO - [Adam] epoch 500/20000 | total=5.059141e+03 | DE=3.628171e+03 | BC=1.430971e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=70.404909581 | int(r*phi^2)=1.00000000 | R_rms=6.023e+01 | R_rel=4.424e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:16:14,961 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:16:15,389 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:16:57,443 - INFO - [Adam] epoch 600/20000 | total=4.613711e+03 | DE=3.310642e+03 | BC=1.303069e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=66.247436305 | int(r*phi^2)=1.00000000 | R_rms=5.754e+01 | R_rel=4.468e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:17:39,851 - INFO - [Adam] epoch 700/20000 | total=4.232704e+03 | DE=3.037976e+03 | BC=1.194727e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=62.489202695 | int(r*phi^2)=1.00000000 | R_rms=5.512e+01 | R_rel=4.514e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:18:21,859 - INFO - [Adam] epoch 800/20000 | total=3.904782e+03 | DE=2.802231e+03 | BC=1.102551e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=59.082236991 | int(r*phi^2)=1.00000000 | R_rms=5.294e+01 | R_rel=4.562e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:19:04,025 - INFO - [Adam] epoch 900/20000 | total=3.620707e+03 | DE=2.597007e+03 | BC=1.023700e+03 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=55.982651327 | int(r*phi^2)=1.00000000 | R_rms=5.096e+01 | R_rel=4.612e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:19:46,007 - INFO - [Adam] epoch 1000/20000 | total=3.373030e+03 | DE=2.417166e+03 | BC=9.558637e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=53.151934173 | int(r*phi^2)=1.00000000 | R_rms=4.916e+01 | R_rel=4.662e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:19:46,207 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:19:46,574 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:20:28,906 - INFO - [Adam] epoch 1100/20000 | total=3.155752e+03 | DE=2.258582e+03 | BC=8.971702e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=50.556883551 | int(r*phi^2)=1.00000000 | R_rms=4.752e+01 | R_rel=4.713e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:21:11,910 - INFO - [Adam] epoch 1200/20000 | total=2.964203e+03 | DE=2.084447e+03 | BC=8.797557e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=48.163428832 | int(r*phi^2)=1.00000000 | R_rms=4.566e+01 | R_rel=4.745e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:21:53,941 - INFO - [Adam] epoch 1300/20000 | total=2.793518e+03 | DE=1.992808e+03 | BC=8.007099e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=45.958870904 | int(r*phi^2)=1.00000000 | R_rms=4.464e+01 | R_rel=4.824e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:22:36,487 - INFO - [Adam] epoch 1400/20000 | total=2.641848e+03 | DE=1.880436e+03 | BC=7.614115e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=43.916679271 | int(r*phi^2)=1.00000000 | R_rms=4.336e+01 | R_rel=4.877e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:23:19,139 - INFO - [Adam] epoch 1500/20000 | total=2.505993e+03 | DE=1.779033e+03 | BC=7.269601e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=42.018832148 | int(r*phi^2)=1.00000000 | R_rms=4.218e+01 | R_rel=4.930e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:23:19,339 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:23:19,704 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:24:02,252 - INFO - [Adam] epoch 1600/20000 | total=2.383767e+03 | DE=1.687332e+03 | BC=6.964351e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=40.249950354 | int(r*phi^2)=1.00000000 | R_rms=4.108e+01 | R_rel=4.984e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:24:45,269 - INFO - [Adam] epoch 1700/20000 | total=2.273350e+03 | DE=1.604063e+03 | BC=6.692869e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=38.596756100 | int(r*phi^2)=1.00000000 | R_rms=4.005e+01 | R_rel=5.039e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:25:27,467 - INFO - [Adam] epoch 1800/20000 | total=2.173221e+03 | DE=1.528163e+03 | BC=6.450583e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=37.047737659 | int(r*phi^2)=1.00000000 | R_rms=3.909e+01 | R_rel=5.093e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:26:09,324 - INFO - [Adam] epoch 1900/20000 | total=2.082101e+03 | DE=1.458735e+03 | BC=6.233657e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=35.592872930 | int(r*phi^2)=1.00000000 | R_rms=3.819e+01 | R_rel=5.149e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:26:51,283 - INFO - [Adam] epoch 2000/20000 | total=1.998905e+03 | DE=1.395020e+03 | BC=6.038849e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=34.223401259 | int(r*phi^2)=1.00000000 | R_rms=3.735e+01 | R_rel=5.204e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:26:51,520 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:26:51,882 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:27:36,684 - INFO - [Adam] epoch 2100/20000 | total=1.922710e+03 | DE=1.336370e+03 | BC=5.863405e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=32.931634547 | int(r*phi^2)=1.00000000 | R_rms=3.656e+01 | R_rel=5.260e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:28:21,331 - INFO - [Adam] epoch 2200/20000 | total=1.852723e+03 | DE=1.282227e+03 | BC=5.704960e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=31.710800350 | int(r*phi^2)=1.00000000 | R_rms=3.581e+01 | R_rel=5.317e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:29:06,397 - INFO - [Adam] epoch 2300/20000 | total=1.788260e+03 | DE=1.232113e+03 | BC=5.561472e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=30.554911005 | int(r*phi^2)=1.00000000 | R_rms=3.510e+01 | R_rel=5.374e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:29:51,976 - INFO - [Adam] epoch 2400/20000 | total=1.728728e+03 | DE=1.185613e+03 | BC=5.431155e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=29.458653984 | int(r*phi^2)=1.00000000 | R_rms=3.443e+01 | R_rel=5.431e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:30:37,688 - INFO - [Adam] epoch 2500/20000 | total=1.673607e+03 | DE=1.142365e+03 | BC=5.312430e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=28.417299633 | int(r*phi^2)=1.00000000 | R_rms=3.380e+01 | R_rel=5.488e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:30:37,895 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:30:38,296 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:31:23,595 - INFO - [Adam] epoch 2600/20000 | total=1.622439e+03 | DE=1.102051e+03 | BC=5.203883e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=27.426623408 | int(r*phi^2)=1.00000000 | R_rms=3.320e+01 | R_rel=5.547e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:32:08,694 - INFO - [Adam] epoch 2700/20000 | total=1.574815e+03 | DE=1.064391e+03 | BC=5.104238e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=26.482840659 | int(r*phi^2)=1.00000000 | R_rms=3.263e+01 | R_rel=5.605e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:32:54,043 - INFO - [Adam] epoch 2800/20000 | total=1.530371e+03 | DE=1.029138e+03 | BC=5.012331e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=25.582552710 | int(r*phi^2)=1.00000000 | R_rms=3.208e+01 | R_rel=5.664e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:33:38,992 - INFO - [Adam] epoch 2900/20000 | total=1.488791e+03 | DE=9.960837e+02 | BC=4.927074e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=24.722701112 | int(r*phi^2)=1.00000000 | R_rms=3.156e+01 | R_rel=5.722e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:34:23,775 - INFO - [Adam] epoch 3000/20000 | total=1.450420e+03 | DE=9.727929e+02 | BC=4.776272e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=23.897728013 | int(r*phi^2)=1.00000000 | R_rms=3.119e+01 | R_rel=5.803e-01 | lr=(2.00e-03, 1.00e-03)
# 2026-09-06 15:34:23,990 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:34:24,359 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:35:09,034 - INFO - [Adam] epoch 3100/20000 | total=1.442465e+03 | DE=9.593285e+02 | BC=4.831362e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=23.728669684 | int(r*phi^2)=1.00000000 | R_rms=3.097e+01 | R_rel=5.802e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:35:53,740 - INFO - [Adam] epoch 3200/20000 | total=1.434701e+03 | DE=9.529938e+02 | BC=4.817077e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=23.561663470 | int(r*phi^2)=1.00000000 | R_rms=3.087e+01 | R_rel=5.812e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:36:38,408 - INFO - [Adam] epoch 3300/20000 | total=1.426781e+03 | DE=9.465324e+02 | BC=4.802484e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=23.390269664 | int(r*phi^2)=1.00000000 | R_rms=3.077e+01 | R_rel=5.822e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:37:22,821 - INFO - [Adam] epoch 3400/20000 | total=1.418707e+03 | DE=9.399659e+02 | BC=4.787408e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=23.214584674 | int(r*phi^2)=1.00000000 | R_rms=3.066e+01 | R_rel=5.834e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:38:08,021 - INFO - [Adam] epoch 3500/20000 | total=1.410485e+03 | DE=9.332967e+02 | BC=4.771882e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=23.034717513 | int(r*phi^2)=1.00000000 | R_rms=3.055e+01 | R_rel=5.846e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:38:08,236 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:38:08,587 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:38:54,320 - INFO - [Adam] epoch 3600/20000 | total=1.402124e+03 | DE=9.265284e+02 | BC=4.755952e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=22.850789543 | int(r*phi^2)=1.00000000 | R_rms=3.044e+01 | R_rel=5.858e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:39:40,036 - INFO - [Adam] epoch 3700/20000 | total=1.393632e+03 | DE=9.196654e+02 | BC=4.739668e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=22.662934203 | int(r*phi^2)=1.00000000 | R_rms=3.033e+01 | R_rel=5.871e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:40:24,818 - INFO - [Adam] epoch 3800/20000 | total=1.385022e+03 | DE=9.127129e+02 | BC=4.723091e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=22.471296692 | int(r*phi^2)=1.00000000 | R_rms=3.021e+01 | R_rel=5.884e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:41:09,634 - INFO - [Adam] epoch 3900/20000 | total=1.376305e+03 | DE=9.056764e+02 | BC=4.706285e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=22.276033586 | int(r*phi^2)=1.00000000 | R_rms=3.009e+01 | R_rel=5.897e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:41:53,783 - INFO - [Adam] epoch 4000/20000 | total=1.367494e+03 | DE=8.985616e+02 | BC=4.689320e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=22.077312342 | int(r*phi^2)=1.00000000 | R_rms=2.998e+01 | R_rel=5.911e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:41:54,002 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:41:54,350 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:42:36,126 - INFO - [Adam] epoch 4100/20000 | total=1.358601e+03 | DE=8.913742e+02 | BC=4.672264e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.875310648 | int(r*phi^2)=1.00000000 | R_rms=2.986e+01 | R_rel=5.924e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:43:18,182 - INFO - [Adam] epoch 4200/20000 | total=1.349638e+03 | DE=8.841195e+02 | BC=4.655185e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.670215638 | int(r*phi^2)=1.00000000 | R_rms=2.973e+01 | R_rel=5.938e-01 | lr=(4.00e-04, 2.00e-04)
# 2026-09-06 15:44:00,334 - INFO - [Adam] epoch 4300/20000 | total=1.344154e+03 | DE=8.796734e+02 | BC=4.644804e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.543952809 | int(r*phi^2)=1.00000000 | R_rms=2.966e+01 | R_rel=5.947e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:44:42,416 - INFO - [Adam] epoch 4400/20000 | total=1.342294e+03 | DE=8.781642e+02 | BC=4.641296e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.501002859 | int(r*phi^2)=1.00000000 | R_rms=2.963e+01 | R_rel=5.950e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:45:24,829 - INFO - [Adam] epoch 4500/20000 | total=1.340376e+03 | DE=8.766075e+02 | BC=4.637684e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.456645996 | int(r*phi^2)=1.00000000 | R_rms=2.961e+01 | R_rel=5.953e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:45:25,030 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:45:25,463 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:46:08,362 - INFO - [Adam] epoch 4600/20000 | total=1.338400e+03 | DE=8.750035e+02 | BC=4.633969e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.410888102 | int(r*phi^2)=1.00000000 | R_rms=2.958e+01 | R_rel=5.956e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:46:51,112 - INFO - [Adam] epoch 4700/20000 | total=1.336368e+03 | DE=8.733529e+02 | BC=4.630153e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.363739685 | int(r*phi^2)=1.00000000 | R_rms=2.955e+01 | R_rel=5.959e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:47:33,011 - INFO - [Adam] epoch 4800/20000 | total=1.334280e+03 | DE=8.716562e+02 | BC=4.626239e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.315215926 | int(r*phi^2)=1.00000000 | R_rms=2.952e+01 | R_rel=5.962e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:48:15,510 - INFO - [Adam] epoch 4900/20000 | total=1.332137e+03 | DE=8.699142e+02 | BC=4.622229e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.265336698 | int(r*phi^2)=1.00000000 | R_rms=2.949e+01 | R_rel=5.966e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:48:57,509 - INFO - [Adam] epoch 5000/20000 | total=1.329941e+03 | DE=8.681281e+02 | BC=4.618128e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.214126522 | int(r*phi^2)=1.00000000 | R_rms=2.946e+01 | R_rel=5.969e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:48:57,724 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:48:58,126 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:49:41,742 - INFO - [Adam] epoch 5100/20000 | total=1.327693e+03 | DE=8.662988e+02 | BC=4.613939e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.161614443 | int(r*phi^2)=1.00000000 | R_rms=2.943e+01 | R_rel=5.973e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:50:25,142 - INFO - [Adam] epoch 5200/20000 | total=1.325394e+03 | DE=8.644276e+02 | BC=4.609666e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.107833862 | int(r*phi^2)=1.00000000 | R_rms=2.940e+01 | R_rel=5.977e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:51:08,990 - INFO - [Adam] epoch 5300/20000 | total=1.323047e+03 | DE=8.625160e+02 | BC=4.605314e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=21.052822280 | int(r*phi^2)=1.00000000 | R_rms=2.937e+01 | R_rel=5.980e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:51:52,539 - INFO - [Adam] epoch 5400/20000 | total=1.320654e+03 | DE=8.605655e+02 | BC=4.600887e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.996621005 | int(r*phi^2)=1.00000000 | R_rms=2.934e+01 | R_rel=5.984e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:52:35,972 - INFO - [Adam] epoch 5500/20000 | total=1.318217e+03 | DE=8.585776e+02 | BC=4.596391e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.939274790 | int(r*phi^2)=1.00000000 | R_rms=2.930e+01 | R_rel=5.988e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:52:36,172 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:52:36,524 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:53:20,421 - INFO - [Adam] epoch 5600/20000 | total=1.315737e+03 | DE=8.565541e+02 | BC=4.591831e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.880831435 | int(r*phi^2)=1.00000000 | R_rms=2.927e+01 | R_rel=5.992e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:54:05,178 - INFO - [Adam] epoch 5700/20000 | total=1.313218e+03 | DE=8.544968e+02 | BC=4.587212e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.821341353 | int(r*phi^2)=1.00000000 | R_rms=2.923e+01 | R_rel=5.996e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:54:49,653 - INFO - [Adam] epoch 5800/20000 | total=1.310661e+03 | DE=8.524075e+02 | BC=4.582539e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.760857109 | int(r*phi^2)=1.00000000 | R_rms=2.920e+01 | R_rel=6.000e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:55:33,852 - INFO - [Adam] epoch 5900/20000 | total=1.308070e+03 | DE=8.502882e+02 | BC=4.577817e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.699432950 | int(r*phi^2)=1.00000000 | R_rms=2.916e+01 | R_rel=6.004e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:56:18,034 - INFO - [Adam] epoch 6000/20000 | total=1.305446e+03 | DE=8.481408e+02 | BC=4.573052e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.637124323 | int(r*phi^2)=1.00000000 | R_rms=2.912e+01 | R_rel=6.008e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:56:18,251 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:56:18,585 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 15:57:02,916 - INFO - [Adam] epoch 6100/20000 | total=1.302792e+03 | DE=8.459672e+02 | BC=4.568249e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.573987409 | int(r*phi^2)=1.00000000 | R_rms=2.909e+01 | R_rel=6.013e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:57:51,285 - INFO - [Adam] epoch 6200/20000 | total=1.300111e+03 | DE=8.437694e+02 | BC=4.563412e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.510078672 | int(r*phi^2)=1.00000000 | R_rms=2.905e+01 | R_rel=6.017e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:58:34,853 - INFO - [Adam] epoch 6300/20000 | total=1.297404e+03 | DE=8.415495e+02 | BC=4.558545e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.445454425 | int(r*phi^2)=1.00000000 | R_rms=2.901e+01 | R_rel=6.021e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 15:59:18,364 - INFO - [Adam] epoch 6400/20000 | total=1.294674e+03 | DE=8.393093e+02 | BC=4.553652e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.380170439 | int(r*phi^2)=1.00000000 | R_rms=2.897e+01 | R_rel=6.026e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:00:02,202 - INFO - [Adam] epoch 6500/20000 | total=1.291925e+03 | DE=8.370507e+02 | BC=4.548738e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.314281581 | int(r*phi^2)=1.00000000 | R_rms=2.893e+01 | R_rel=6.030e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:00:02,416 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:00:02,765 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:00:47,363 - INFO - [Adam] epoch 6600/20000 | total=1.289156e+03 | DE=8.347757e+02 | BC=4.543804e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.247841490 | int(r*phi^2)=1.00000000 | R_rms=2.889e+01 | R_rel=6.035e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:01:31,579 - INFO - [Adam] epoch 6700/20000 | total=1.286372e+03 | DE=8.324862e+02 | BC=4.538854e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.180902308 | int(r*phi^2)=1.00000000 | R_rms=2.885e+01 | R_rel=6.039e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:02:15,995 - INFO - [Adam] epoch 6800/20000 | total=1.283573e+03 | DE=8.301839e+02 | BC=4.533890e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.113514439 | int(r*phi^2)=1.00000000 | R_rms=2.881e+01 | R_rel=6.044e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:03:00,186 - INFO - [Adam] epoch 6900/20000 | total=1.280762e+03 | DE=8.278705e+02 | BC=4.528912e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=20.045726364 | int(r*phi^2)=1.00000000 | R_rms=2.877e+01 | R_rel=6.048e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:03:44,029 - INFO - [Adam] epoch 7000/20000 | total=1.277940e+03 | DE=8.255477e+02 | BC=4.523923e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.977584490 | int(r*phi^2)=1.00000000 | R_rms=2.873e+01 | R_rel=6.052e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:03:44,244 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:03:44,593 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:04:28,326 - INFO - [Adam] epoch 7100/20000 | total=1.275109e+03 | DE=8.232172e+02 | BC=4.518921e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.909133039 | int(r*phi^2)=1.00000000 | R_rms=2.869e+01 | R_rel=6.057e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:05:11,958 - INFO - [Adam] epoch 7200/20000 | total=1.272271e+03 | DE=8.208804e+02 | BC=4.513906e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.840413979 | int(r*phi^2)=1.00000000 | R_rms=2.865e+01 | R_rel=6.061e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:05:55,410 - INFO - [Adam] epoch 7300/20000 | total=1.269426e+03 | DE=8.185387e+02 | BC=4.508878e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.771466979 | int(r*phi^2)=1.00000000 | R_rms=2.861e+01 | R_rel=6.065e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:06:38,924 - INFO - [Adam] epoch 7400/20000 | total=1.266577e+03 | DE=8.161935e+02 | BC=4.503833e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.702329402 | int(r*phi^2)=1.00000000 | R_rms=2.857e+01 | R_rel=6.069e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:07:22,540 - INFO - [Adam] epoch 7500/20000 | total=1.263723e+03 | DE=8.138459e+02 | BC=4.498768e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.633036316 | int(r*phi^2)=1.00000000 | R_rms=2.853e+01 | R_rel=6.073e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:07:22,764 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:07:23,174 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:08:04,305 - INFO - [Adam] epoch 7600/20000 | total=1.260865e+03 | DE=8.114971e+02 | BC=4.493679e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.563620531 | int(r*phi^2)=1.00000000 | R_rms=2.849e+01 | R_rel=6.077e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:08:44,938 - INFO - [Adam] epoch 7700/20000 | total=1.258004e+03 | DE=8.091481e+02 | BC=4.488560e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.494112653 | int(r*phi^2)=1.00000000 | R_rms=2.845e+01 | R_rel=6.080e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:09:25,987 - INFO - [Adam] epoch 7800/20000 | total=1.255140e+03 | DE=8.067996e+02 | BC=4.483402e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.424541152 | int(r*phi^2)=1.00000000 | R_rms=2.840e+01 | R_rel=6.083e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:10:07,020 - INFO - [Adam] epoch 7900/20000 | total=1.252272e+03 | DE=8.044523e+02 | BC=4.478193e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.354932444 | int(r*phi^2)=1.00000000 | R_rms=2.836e+01 | R_rel=6.086e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:10:48,236 - INFO - [Adam] epoch 8000/20000 | total=1.249398e+03 | DE=8.021065e+02 | BC=4.472918e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.285310978 | int(r*phi^2)=1.00000000 | R_rms=2.832e+01 | R_rel=6.088e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:10:48,452 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:10:48,836 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:11:30,238 - INFO - [Adam] epoch 8100/20000 | total=1.246518e+03 | DE=7.997623e+02 | BC=4.467555e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.215699338 | int(r*phi^2)=1.00000000 | R_rms=2.828e+01 | R_rel=6.090e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:12:10,851 - INFO - [Adam] epoch 8200/20000 | total=1.243627e+03 | DE=7.974191e+02 | BC=4.462074e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.146118352 | int(r*phi^2)=1.00000000 | R_rms=2.824e+01 | R_rel=6.091e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:12:51,624 - INFO - [Adam] epoch 8300/20000 | total=1.240718e+03 | DE=7.950754e+02 | BC=4.456429e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.076587222 | int(r*phi^2)=1.00000000 | R_rms=2.820e+01 | R_rel=6.090e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:13:32,100 - INFO - [Adam] epoch 8400/20000 | total=1.237783e+03 | DE=7.927278e+02 | BC=4.450550e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=19.007123689 | int(r*phi^2)=1.00000000 | R_rms=2.816e+01 | R_rel=6.088e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:14:12,949 - INFO - [Adam] epoch 8500/20000 | total=1.234802e+03 | DE=7.903694e+02 | BC=4.444325e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.937744296 | int(r*phi^2)=1.00000000 | R_rms=2.811e+01 | R_rel=6.083e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:14:13,165 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:14:13,533 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:14:54,631 - INFO - [Adam] epoch 8600/20000 | total=1.231741e+03 | DE=7.879851e+02 | BC=4.437559e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.868464927 | int(r*phi^2)=1.00000000 | R_rms=2.807e+01 | R_rel=6.074e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:15:35,497 - INFO - [Adam] epoch 8700/20000 | total=1.228528e+03 | DE=7.855397e+02 | BC=4.429887e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.799302144 | int(r*phi^2)=1.00000000 | R_rms=2.803e+01 | R_rel=6.058e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:16:16,813 - INFO - [Adam] epoch 8800/20000 | total=1.225003e+03 | DE=7.829473e+02 | BC=4.420559e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.730277136 | int(r*phi^2)=1.00000000 | R_rms=2.798e+01 | R_rel=6.028e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:16:58,263 - INFO - [Adam] epoch 8900/20000 | total=1.220802e+03 | DE=7.800045e+02 | BC=4.407970e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.661427322 | int(r*phi^2)=1.00000000 | R_rms=2.793e+01 | R_rel=5.973e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:17:39,829 - INFO - [Adam] epoch 9000/20000 | total=1.215292e+03 | DE=7.763733e+02 | BC=4.389189e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.592826766 | int(r*phi^2)=1.00000000 | R_rms=2.786e+01 | R_rel=5.869e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:17:40,045 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:17:40,396 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:18:22,080 - INFO - [Adam] epoch 9100/20000 | total=1.208453e+03 | DE=7.708587e+02 | BC=4.375941e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.524568398 | int(r*phi^2)=1.00000000 | R_rms=2.776e+01 | R_rel=5.704e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:19:03,027 - INFO - [Adam] epoch 9200/20000 | total=1.200122e+03 | DE=7.676843e+02 | BC=4.324381e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.456730255 | int(r*phi^2)=1.00000000 | R_rms=2.771e+01 | R_rel=5.461e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:19:44,264 - INFO - [Adam] epoch 9300/20000 | total=1.187303e+03 | DE=7.633355e+02 | BC=4.239671e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.389350797 | int(r*phi^2)=1.00000000 | R_rms=2.763e+01 | R_rel=5.080e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:20:25,392 - INFO - [Adam] epoch 9400/20000 | total=1.163816e+03 | DE=7.270509e+02 | BC=4.367651e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.322676486 | int(r*phi^2)=1.00000000 | R_rms=2.696e+01 | R_rel=4.366e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:21:06,358 - INFO - [Adam] epoch 9500/20000 | total=1.114438e+03 | DE=6.932912e+02 | BC=4.211463e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.257262856 | int(r*phi^2)=1.00000000 | R_rms=2.633e+01 | R_rel=3.146e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:21:06,558 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:21:06,983 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:21:48,757 - INFO - [Adam] epoch 9600/20000 | total=1.061377e+03 | DE=6.687074e+02 | BC=3.926696e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.192924073 | int(r*phi^2)=1.00000000 | R_rms=2.586e+01 | R_rel=2.206e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:22:31,059 - INFO - [Adam] epoch 9700/20000 | total=1.039094e+03 | DE=7.875096e+02 | BC=2.515848e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.129652586 | int(r*phi^2)=1.00000000 | R_rms=2.806e+01 | R_rel=1.956e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:23:12,767 - INFO - [Adam] epoch 9800/20000 | total=1.360485e+03 | DE=3.831582e+02 | BC=9.773267e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.067328439 | int(r*phi^2)=1.00000000 | R_rms=1.957e+01 | R_rel=1.928e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:23:54,408 - INFO - [Adam] epoch 9900/20000 | total=9.927927e+02 | DE=6.994981e+02 | BC=2.932946e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=18.003441376 | int(r*phi^2)=1.00000000 | R_rms=2.645e+01 | R_rel=1.488e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:24:36,973 - INFO - [Adam] epoch 10000/20000 | total=1.144803e+03 | DE=7.401697e+02 | BC=4.046330e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.940362653 | int(r*phi^2)=1.00000000 | R_rms=2.721e+01 | R_rel=2.924e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:24:37,189 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:24:37,605 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:25:18,920 - INFO - [Adam] epoch 10100/20000 | total=9.921207e+02 | DE=6.894844e+02 | BC=3.026363e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.875237031 | int(r*phi^2)=1.00000000 | R_rms=2.626e+01 | R_rel=1.720e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:26:00,820 - INFO - [Adam] epoch 10200/20000 | total=9.284283e+02 | DE=6.817246e+02 | BC=2.467037e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.814898558 | int(r*phi^2)=1.00000000 | R_rms=2.611e+01 | R_rel=1.111e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:26:43,052 - INFO - [Adam] epoch 10300/20000 | total=9.734950e+02 | DE=6.622873e+02 | BC=3.112077e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.749909533 | int(r*phi^2)=1.00000000 | R_rms=2.573e+01 | R_rel=1.688e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:27:25,668 - INFO - [Adam] epoch 10400/20000 | total=1.251254e+03 | DE=9.872317e+02 | BC=2.640227e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.690388157 | int(r*phi^2)=1.00000000 | R_rms=3.142e+01 | R_rel=2.465e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:28:07,650 - INFO - [Adam] epoch 10500/20000 | total=9.092716e+02 | DE=6.501287e+02 | BC=2.591429e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.625689325 | int(r*phi^2)=1.00000000 | R_rms=2.550e+01 | R_rel=1.234e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:28:07,867 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:28:08,251 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:28:50,433 - INFO - [Adam] epoch 10600/20000 | total=1.728412e+03 | DE=9.814934e+02 | BC=7.469184e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.566432186 | int(r*phi^2)=1.00000000 | R_rms=3.133e+01 | R_rel=5.634e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:29:32,531 - INFO - [Adam] epoch 10700/20000 | total=1.065231e+03 | DE=6.959076e+02 | BC=3.693235e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.477804857 | int(r*phi^2)=1.00000000 | R_rms=2.638e+01 | R_rel=3.044e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:30:14,698 - INFO - [Adam] epoch 10800/20000 | total=1.027825e+03 | DE=6.785613e+02 | BC=3.492639e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.416643475 | int(r*phi^2)=1.00000000 | R_rms=2.605e+01 | R_rel=2.586e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:30:56,814 - INFO - [Adam] epoch 10900/20000 | total=9.704585e+02 | DE=6.584313e+02 | BC=3.120273e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.357558296 | int(r*phi^2)=1.00000000 | R_rms=2.566e+01 | R_rel=1.901e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:31:39,497 - INFO - [Adam] epoch 11000/20000 | total=8.461825e+02 | DE=6.339227e+02 | BC=2.122598e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.300918110 | int(r*phi^2)=1.00000000 | R_rms=2.518e+01 | R_rel=9.286e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:31:39,714 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:31:40,081 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:32:24,463 - INFO - [Adam] epoch 11100/20000 | total=1.465256e+03 | DE=6.833154e+02 | BC=7.819407e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.238819567 | int(r*phi^2)=1.00000000 | R_rms=2.614e+01 | R_rel=4.636e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:33:08,845 - INFO - [Adam] epoch 11200/20000 | total=1.010205e+03 | DE=6.635616e+02 | BC=3.466434e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.167631888 | int(r*phi^2)=1.00000000 | R_rms=2.576e+01 | R_rel=2.503e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:33:52,089 - INFO - [Adam] epoch 11300/20000 | total=9.149047e+02 | DE=6.277749e+02 | BC=2.871297e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.109803187 | int(r*phi^2)=1.00000000 | R_rms=2.506e+01 | R_rel=1.583e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:34:34,881 - INFO - [Adam] epoch 11400/20000 | total=8.029931e+02 | DE=3.936096e+02 | BC=4.093835e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=17.057309420 | int(r*phi^2)=1.00000000 | R_rms=1.984e+01 | R_rel=5.515e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:35:16,945 - INFO - [Adam] epoch 11500/20000 | total=9.567685e+02 | DE=6.348391e+02 | BC=3.219294e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.988286226 | int(r*phi^2)=1.00000000 | R_rms=2.520e+01 | R_rel=2.001e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:35:17,178 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:35:17,595 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:36:00,709 - INFO - [Adam] epoch 11600/20000 | total=7.012204e+02 | DE=5.705532e+02 | BC=1.306673e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.934239899 | int(r*phi^2)=1.00000000 | R_rms=2.389e+01 | R_rel=5.810e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:36:44,758 - INFO - [Adam] epoch 11700/20000 | total=1.009607e+03 | DE=6.436947e+02 | BC=3.659125e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.857509545 | int(r*phi^2)=1.00000000 | R_rms=2.537e+01 | R_rel=2.643e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:37:28,724 - INFO - [Adam] epoch 11800/20000 | total=9.523735e+02 | DE=6.334643e+02 | BC=3.189092e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.800441470 | int(r*phi^2)=1.00000000 | R_rms=2.517e+01 | R_rel=2.037e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:38:12,340 - INFO - [Adam] epoch 11900/20000 | total=7.497338e+02 | DE=5.550298e+02 | BC=1.947040e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.746462254 | int(r*phi^2)=1.00000000 | R_rms=2.356e+01 | R_rel=8.530e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:38:56,373 - INFO - [Adam] epoch 12000/20000 | total=9.303687e+02 | DE=8.093041e+02 | BC=1.210646e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.696675524 | int(r*phi^2)=1.00000000 | R_rms=2.845e+01 | R_rel=1.578e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:38:56,606 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:38:56,975 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:39:39,822 - INFO - [Adam] epoch 12100/20000 | total=5.924724e+02 | DE=5.451468e+02 | BC=4.732557e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.645779765 | int(r*phi^2)=1.00000000 | R_rms=2.335e+01 | R_rel=5.304e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:40:23,504 - INFO - [Adam] epoch 12200/20000 | total=4.916276e+02 | DE=4.308063e+02 | BC=6.082129e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.598153386 | int(r*phi^2)=1.00000000 | R_rms=2.076e+01 | R_rel=3.756e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:41:08,220 - INFO - [Adam] epoch 12300/20000 | total=8.111283e+02 | DE=7.396179e+02 | BC=7.151033e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.547633399 | int(r*phi^2)=1.00000000 | R_rms=2.720e+01 | R_rel=1.055e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:41:53,036 - INFO - [Adam] epoch 12400/20000 | total=4.274912e+02 | DE=3.951536e+02 | BC=3.233755e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.504937289 | int(r*phi^2)=1.00000000 | R_rms=1.988e+01 | R_rel=3.283e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:42:38,050 - INFO - [Adam] epoch 12500/20000 | total=8.675181e+02 | DE=5.667029e+02 | BC=3.008151e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.451692168 | int(r*phi^2)=1.00000000 | R_rms=2.381e+01 | R_rel=1.503e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:42:38,336 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:42:38,785 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:43:22,033 - INFO - [Adam] epoch 12600/20000 | total=3.971597e+02 | DE=3.559410e+02 | BC=4.121870e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.404973227 | int(r*phi^2)=1.00000000 | R_rms=1.887e+01 | R_rel=3.063e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:44:05,950 - INFO - [Adam] epoch 12700/20000 | total=3.681031e+02 | DE=3.233365e+02 | BC=4.476656e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.369838266 | int(r*phi^2)=1.00000000 | R_rms=1.798e+01 | R_rel=2.961e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:44:49,718 - INFO - [Adam] epoch 12800/20000 | total=7.439044e+02 | DE=4.609375e+02 | BC=2.829669e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.319502303 | int(r*phi^2)=1.00000000 | R_rms=2.147e+01 | R_rel=9.801e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:45:32,999 - INFO - [Adam] epoch 12900/20000 | total=3.320302e+02 | DE=3.055987e+02 | BC=2.643155e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.280146528 | int(r*phi^2)=1.00000000 | R_rms=1.748e+01 | R_rel=2.615e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:46:16,515 - INFO - [Adam] epoch 13000/20000 | total=9.198382e+02 | DE=6.248277e+02 | BC=2.950106e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.216472750 | int(r*phi^2)=1.00000000 | R_rms=2.500e+01 | R_rel=1.889e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:46:16,782 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:46:17,198 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:47:00,330 - INFO - [Adam] epoch 13100/20000 | total=4.093688e+02 | DE=3.396198e+02 | BC=6.974902e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.159032763 | int(r*phi^2)=1.00000000 | R_rms=1.843e+01 | R_rel=3.605e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:47:44,596 - INFO - [Adam] epoch 13200/20000 | total=2.877058e+02 | DE=2.647674e+02 | BC=2.293834e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.126852219 | int(r*phi^2)=1.00000000 | R_rms=1.627e+01 | R_rel=2.343e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:48:29,413 - INFO - [Adam] epoch 13300/20000 | total=6.019142e+02 | DE=4.932861e+02 | BC=1.086281e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.078901337 | int(r*phi^2)=1.00000000 | R_rms=2.221e+01 | R_rel=7.072e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:49:14,495 - INFO - [Adam] epoch 13400/20000 | total=2.537344e+02 | DE=2.345845e+02 | BC=1.914995e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=16.044776314 | int(r*phi^2)=1.00000000 | R_rms=1.532e+01 | R_rel=2.135e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:49:58,444 - INFO - [Adam] epoch 13500/20000 | total=1.075132e+03 | DE=6.609951e+02 | BC=4.141373e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.985591832 | int(r*phi^2)=1.00000000 | R_rms=2.571e+01 | R_rel=2.780e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:49:58,709 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:49:59,146 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:50:39,294 - INFO - [Adam] epoch 13600/20000 | total=8.012616e+02 | DE=5.428742e+02 | BC=2.583875e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.913596857 | int(r*phi^2)=1.00000000 | R_rms=2.330e+01 | R_rel=1.327e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:51:19,178 - INFO - [Adam] epoch 13700/20000 | total=2.368831e+02 | DE=2.196766e+02 | BC=1.720645e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.869862256 | int(r*phi^2)=1.00000000 | R_rms=1.482e+01 | R_rel=2.070e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:52:00,788 - INFO - [Adam] epoch 13800/20000 | total=3.074139e+02 | DE=1.397858e+02 | BC=1.676281e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.844684155 | int(r*phi^2)=1.00000000 | R_rms=1.182e+01 | R_rel=1.829e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:52:42,291 - INFO - [Adam] epoch 13900/20000 | total=9.004131e+02 | DE=5.866816e+02 | BC=3.137315e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.768755641 | int(r*phi^2)=1.00000000 | R_rms=2.422e+01 | R_rel=1.825e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:53:23,541 - INFO - [Adam] epoch 14000/20000 | total=3.027943e+02 | DE=2.607626e+02 | BC=4.203164e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.711888103 | int(r*phi^2)=1.00000000 | R_rms=1.615e+01 | R_rel=2.756e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:53:23,836 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:53:24,365 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:54:07,873 - INFO - [Adam] epoch 14100/20000 | total=1.721326e+02 | DE=1.623688e+02 | BC=9.763823e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.687071377 | int(r*phi^2)=1.00000000 | R_rms=1.274e+01 | R_rel=1.647e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:54:51,589 - INFO - [Adam] epoch 14200/20000 | total=7.542782e+02 | DE=5.543507e+02 | BC=1.999275e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.635027728 | int(r*phi^2)=1.00000000 | R_rms=2.354e+01 | R_rel=1.179e-01 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:55:35,438 - INFO - [Adam] epoch 14300/20000 | total=1.550817e+02 | DE=1.462986e+02 | BC=8.783065e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.598546269 | int(r*phi^2)=1.00000000 | R_rms=1.210e+01 | R_rel=1.546e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:56:23,021 - INFO - [Adam] epoch 14400/20000 | total=5.126369e+02 | DE=4.324206e+02 | BC=8.021630e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.562155212 | int(r*phi^2)=1.00000000 | R_rms=2.079e+01 | R_rel=5.891e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:57:07,820 - INFO - [Adam] epoch 14500/20000 | total=1.818499e+02 | DE=1.144577e+02 | BC=6.739216e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.523226857 | int(r*phi^2)=1.00000000 | R_rms=1.070e+01 | R_rel=1.538e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:57:08,119 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:57:08,640 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 16:57:52,469 - INFO - [Adam] epoch 14600/20000 | total=2.566010e+02 | DE=1.953964e+02 | BC=6.120459e+01 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.494483522 | int(r*phi^2)=1.00000000 | R_rms=1.398e+01 | R_rel=1.651e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:58:37,301 - INFO - [Adam] epoch 14700/20000 | total=1.108281e+02 | DE=1.045509e+02 | BC=6.277152e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.472919769 | int(r*phi^2)=1.00000000 | R_rms=1.023e+01 | R_rel=1.249e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 16:59:20,804 - INFO - [Adam] epoch 14800/20000 | total=9.271389e+01 | DE=8.657506e+01 | BC=6.138832e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.453667194 | int(r*phi^2)=1.00000000 | R_rms=9.305e+00 | R_rel=1.118e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 17:00:05,633 - INFO - [Adam] epoch 14900/20000 | total=7.764872e+02 | DE=1.086650e+02 | BC=6.678222e+02 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.434496284 | int(r*phi^2)=1.00000000 | R_rms=1.042e+01 | R_rel=2.076e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 17:00:49,882 - INFO - [Adam] epoch 15000/20000 | total=7.855789e+01 | DE=7.352185e+01 | BC=5.036045e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.393867722 | int(r*phi^2)=1.00000000 | R_rms=8.574e+00 | R_rel=1.011e-02 | lr=(8.00e-05, 4.00e-05)
# 2026-09-06 17:00:50,149 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 17:00:50,619 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 17:01:35,848 - INFO - [Adam] epoch 15100/20000 | total=7.523861e+01 | DE=6.930657e+01 | BC=5.932039e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.389982371 | int(r*phi^2)=1.00000000 | R_rms=8.325e+00 | R_rel=9.863e-03 | lr=(1.60e-05, 8.00e-06)
# 2026-09-06 17:02:20,981 - INFO - [Adam] epoch 15200/20000 | total=7.253324e+01 | DE=6.660668e+01 | BC=5.926560e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.386138621 | int(r*phi^2)=1.00000000 | R_rms=8.161e+00 | R_rel=9.643e-03 | lr=(1.60e-05, 8.00e-06)
# 2026-09-06 17:03:07,280 - INFO - [Adam] epoch 15300/20000 | total=6.988211e+01 | DE=6.395255e+01 | BC=5.929566e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.382177497 | int(r*phi^2)=1.00000000 | R_rms=7.997e+00 | R_rel=9.425e-03 | lr=(1.60e-05, 8.00e-06)
# 2026-09-06 17:03:53,279 - INFO - [Adam] epoch 15400/20000 | total=6.726829e+01 | DE=6.132819e+01 | BC=5.940100e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.378097083 | int(r*phi^2)=1.00000000 | R_rms=7.831e+00 | R_rel=9.207e-03 | lr=(1.60e-05, 8.00e-06)
# 2026-09-06 17:04:39,491 - INFO - [Adam] epoch 15500/20000 | total=6.468778e+01 | DE=5.873154e+01 | BC=5.956247e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.373895586 | int(r*phi^2)=1.00000000 | R_rms=7.664e+00 | R_rel=8.989e-03 | lr=(1.60e-05, 8.00e-06)
# 2026-09-06 17:04:39,747 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 17:04:40,212 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 17:05:25,413 - INFO - [Adam] epoch 15600/20000 | total=6.214166e+01 | DE=5.616474e+01 | BC=5.976920e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.369571261 | int(r*phi^2)=1.00000000 | R_rms=7.494e+00 | R_rel=8.771e-03 | lr=(1.60e-05, 8.00e-06)
# 2026-09-06 17:06:10,193 - INFO - [Adam] epoch 15700/20000 | total=5.963338e+01 | DE=5.363190e+01 | BC=6.001486e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.365122379 | int(r*phi^2)=1.00000000 | R_rms=7.323e+00 | R_rel=8.552e-03 | lr=(1.60e-05, 8.00e-06)
# 2026-09-06 17:06:55,358 - INFO - [Adam] epoch 15800/20000 | total=5.716789e+01 | DE=5.113837e+01 | BC=6.029511e+00 | Norm=0.000000e+00 | L2=0.000e+00 | lambda=15.360547208 | int(r*phi^2)=1.00000000 | R_rms=7.151e+00 | R_rel=8.332e-03 | lr=(1.60e-05, 8.00e-06)
# ...
# 2026-09-06 18:29:31,588 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:29:32,171 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:30:27,070 - INFO - [L-BFGS] iter 5600/10000 | global_step=25600 | block_iter=100 | block_evals=126 | total_evals=7034 | total=4.303730e-03 | DE=4.165131e-03 | BC=1.385990e-04 | lambda=10.268376887 | int(r*phi^2)=1.00000000 | R_rms=6.454e-02 | R_rel=7.933e-05
# 2026-09-06 18:31:20,972 - INFO - [L-BFGS] iter 5700/10000 | global_step=25700 | block_iter=100 | block_evals=124 | total_evals=7158 | total=4.211345e-03 | DE=4.054613e-03 | BC=1.567312e-04 | lambda=10.268237757 | int(r*phi^2)=1.00000000 | R_rms=6.368e-02 | R_rel=7.827e-05
# 2026-09-06 18:32:14,251 - INFO - [L-BFGS] iter 5800/10000 | global_step=25800 | block_iter=100 | block_evals=122 | total_evals=7280 | total=3.986633e-03 | DE=3.894342e-03 | BC=9.229093e-05 | lambda=10.265242600 | int(r*phi^2)=1.00000000 | R_rms=6.240e-02 | R_rel=7.672e-05
# 2026-09-06 18:33:09,332 - INFO - [L-BFGS] iter 5900/10000 | global_step=25900 | block_iter=100 | block_evals=127 | total_evals=7407 | total=3.896727e-03 | DE=3.804415e-03 | BC=9.231226e-05 | lambda=10.267189893 | int(r*phi^2)=1.00000000 | R_rms=6.168e-02 | R_rel=7.582e-05
# 2026-09-06 18:34:04,021 - INFO - [L-BFGS] iter 6000/10000 | global_step=26000 | block_iter=100 | block_evals=127 | total_evals=7534 | total=3.767726e-03 | DE=3.638793e-03 | BC=1.289333e-04 | lambda=10.267534247 | int(r*phi^2)=1.00000000 | R_rms=6.032e-02 | R_rel=7.415e-05
# 2026-09-06 18:34:04,230 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:34:04,683 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:34:59,569 - INFO - [L-BFGS] iter 6100/10000 | global_step=26100 | block_iter=100 | block_evals=126 | total_evals=7660 | total=3.552851e-03 | DE=3.454831e-03 | BC=9.801980e-05 | lambda=10.266058093 | int(r*phi^2)=1.00000000 | R_rms=5.878e-02 | R_rel=7.226e-05
# 2026-09-06 18:35:53,984 - INFO - [L-BFGS] iter 6200/10000 | global_step=26200 | block_iter=100 | block_evals=126 | total_evals=7786 | total=3.413472e-03 | DE=3.362571e-03 | BC=5.090129e-05 | lambda=10.263415714 | int(r*phi^2)=1.00000000 | R_rms=5.799e-02 | R_rel=7.129e-05
# 2026-09-06 18:36:47,163 - INFO - [L-BFGS] iter 6300/10000 | global_step=26300 | block_iter=100 | block_evals=123 | total_evals=7909 | total=3.228854e-03 | DE=3.209805e-03 | BC=1.904974e-05 | lambda=10.258339804 | int(r*phi^2)=1.00000000 | R_rms=5.666e-02 | R_rel=6.967e-05
# 2026-09-06 18:37:43,598 - INFO - [L-BFGS] iter 6400/10000 | global_step=26400 | block_iter=100 | block_evals=131 | total_evals=8040 | total=2.352784e-03 | DE=2.351842e-03 | BC=9.421043e-07 | lambda=10.257679098 | int(r*phi^2)=1.00000000 | R_rms=4.850e-02 | R_rel=5.964e-05
# 2026-09-06 18:38:40,078 - INFO - [L-BFGS] iter 6500/10000 | global_step=26500 | block_iter=100 | block_evals=131 | total_evals=8171 | total=2.007458e-03 | DE=2.006777e-03 | BC=6.802686e-07 | lambda=10.257876746 | int(r*phi^2)=1.00000000 | R_rms=4.480e-02 | R_rel=5.509e-05
# 2026-09-06 18:38:40,278 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:38:40,762 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:39:34,977 - INFO - [L-BFGS] iter 6600/10000 | global_step=26600 | block_iter=100 | block_evals=123 | total_evals=8294 | total=1.152407e-03 | DE=1.146441e-03 | BC=5.966528e-06 | lambda=10.259760300 | int(r*phi^2)=1.00000000 | R_rms=3.386e-02 | R_rel=4.164e-05
# 2026-09-06 18:40:30,408 - INFO - [L-BFGS] iter 6700/10000 | global_step=26700 | block_iter=100 | block_evals=127 | total_evals=8421 | total=5.717844e-04 | DE=5.505691e-04 | BC=2.121530e-05 | lambda=10.260674412 | int(r*phi^2)=1.00000000 | R_rms=2.346e-02 | R_rel=2.885e-05
# 2026-09-06 18:41:23,742 - INFO - [L-BFGS] iter 6800/10000 | global_step=26800 | block_iter=100 | block_evals=122 | total_evals=8543 | total=2.454655e-04 | DE=2.177338e-04 | BC=2.773164e-05 | lambda=10.261325780 | int(r*phi^2)=1.00000000 | R_rms=1.476e-02 | R_rel=1.814e-05
# 2026-09-06 18:42:19,906 - INFO - [L-BFGS] iter 6900/10000 | global_step=26900 | block_iter=100 | block_evals=128 | total_evals=8671 | total=2.437390e-04 | DE=2.150551e-04 | BC=2.868383e-05 | lambda=10.261331362 | int(r*phi^2)=1.00000000 | R_rms=1.466e-02 | R_rel=1.803e-05
# 2026-09-06 18:43:15,640 - INFO - [L-BFGS] iter 7000/10000 | global_step=27000 | block_iter=100 | block_evals=127 | total_evals=8798 | total=2.385819e-04 | DE=2.097048e-04 | BC=2.887711e-05 | lambda=10.261253226 | int(r*phi^2)=1.00000000 | R_rms=1.448e-02 | R_rel=1.781e-05
# 2026-09-06 18:43:15,823 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:43:16,307 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:44:10,492 - INFO - [L-BFGS] iter 7100/10000 | global_step=27100 | block_iter=100 | block_evals=123 | total_evals=8921 | total=2.321631e-04 | DE=2.050547e-04 | BC=2.710841e-05 | lambda=10.261093601 | int(r*phi^2)=1.00000000 | R_rms=1.432e-02 | R_rel=1.761e-05
# 2026-09-06 18:45:06,971 - INFO - [L-BFGS] iter 7200/10000 | global_step=27200 | block_iter=100 | block_evals=129 | total_evals=9050 | total=2.279134e-04 | DE=2.021333e-04 | BC=2.578009e-05 | lambda=10.260990740 | int(r*phi^2)=1.00000000 | R_rms=1.422e-02 | R_rel=1.748e-05
# 2026-09-06 18:46:02,887 - INFO - [L-BFGS] iter 7300/10000 | global_step=27300 | block_iter=100 | block_evals=127 | total_evals=9177 | total=2.248870e-04 | DE=1.999675e-04 | BC=2.491948e-05 | lambda=10.260949407 | int(r*phi^2)=1.00000000 | R_rms=1.414e-02 | R_rel=1.739e-05
# 2026-09-06 18:46:56,936 - INFO - [L-BFGS] iter 7400/10000 | global_step=27400 | block_iter=100 | block_evals=121 | total_evals=9298 | total=2.234078e-04 | DE=1.991384e-04 | BC=2.426944e-05 | lambda=10.260811035 | int(r*phi^2)=1.00000000 | R_rms=1.411e-02 | R_rel=1.735e-05
# 2026-09-06 18:47:52,918 - INFO - [L-BFGS] iter 7500/10000 | global_step=27500 | block_iter=100 | block_evals=126 | total_evals=9424 | total=2.224305e-04 | DE=1.991277e-04 | BC=2.330279e-05 | lambda=10.260716305 | int(r*phi^2)=1.00000000 | R_rms=1.411e-02 | R_rel=1.735e-05
# 2026-09-06 18:47:53,152 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:47:53,668 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:48:47,618 - INFO - [L-BFGS] iter 7600/10000 | global_step=27600 | block_iter=100 | block_evals=122 | total_evals=9546 | total=2.220341e-04 | DE=1.990562e-04 | BC=2.297788e-05 | lambda=10.260666973 | int(r*phi^2)=1.00000000 | R_rms=1.411e-02 | R_rel=1.735e-05
# 2026-09-06 18:49:44,133 - INFO - [L-BFGS] iter 7700/10000 | global_step=27700 | block_iter=100 | block_evals=129 | total_evals=9675 | total=2.203016e-04 | DE=1.972423e-04 | BC=2.305932e-05 | lambda=10.260667476 | int(r*phi^2)=1.00000000 | R_rms=1.404e-02 | R_rel=1.727e-05
# 2026-09-06 18:50:37,483 - INFO - [L-BFGS] iter 7800/10000 | global_step=27800 | block_iter=100 | block_evals=120 | total_evals=9795 | total=2.185087e-04 | DE=1.956953e-04 | BC=2.281336e-05 | lambda=10.260586473 | int(r*phi^2)=1.00000000 | R_rms=1.399e-02 | R_rel=1.720e-05
# 2026-09-06 18:51:32,081 - INFO - [L-BFGS] iter 7900/10000 | global_step=27900 | block_iter=100 | block_evals=124 | total_evals=9919 | total=2.166175e-04 | DE=1.942313e-04 | BC=2.238621e-05 | lambda=10.260628295 | int(r*phi^2)=1.00000000 | R_rms=1.394e-02 | R_rel=1.714e-05
# 2026-09-06 18:52:29,530 - INFO - [L-BFGS] iter 8000/10000 | global_step=28000 | block_iter=100 | block_evals=129 | total_evals=10048 | total=2.148670e-04 | DE=1.924214e-04 | BC=2.244562e-05 | lambda=10.260634153 | int(r*phi^2)=1.00000000 | R_rms=1.387e-02 | R_rel=1.706e-05
# 2026-09-06 18:52:29,779 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:52:30,199 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:53:24,481 - INFO - [L-BFGS] iter 8100/10000 | global_step=28100 | block_iter=100 | block_evals=121 | total_evals=10169 | total=2.129859e-04 | DE=1.907375e-04 | BC=2.224835e-05 | lambda=10.260543260 | int(r*phi^2)=1.00000000 | R_rms=1.381e-02 | R_rel=1.698e-05
# 2026-09-06 18:54:20,128 - INFO - [L-BFGS] iter 8200/10000 | global_step=28200 | block_iter=100 | block_evals=125 | total_evals=10294 | total=2.111641e-04 | DE=1.893862e-04 | BC=2.177791e-05 | lambda=10.260579377 | int(r*phi^2)=1.00000000 | R_rms=1.376e-02 | R_rel=1.692e-05
# 2026-09-06 18:55:15,310 - INFO - [L-BFGS] iter 8300/10000 | global_step=28300 | block_iter=100 | block_evals=124 | total_evals=10418 | total=2.092430e-04 | DE=1.874388e-04 | BC=2.180426e-05 | lambda=10.260553476 | int(r*phi^2)=1.00000000 | R_rms=1.369e-02 | R_rel=1.683e-05
# 2026-09-06 18:56:11,109 - INFO - [L-BFGS] iter 8400/10000 | global_step=28400 | block_iter=100 | block_evals=125 | total_evals=10543 | total=2.073670e-04 | DE=1.858041e-04 | BC=2.156292e-05 | lambda=10.260515649 | int(r*phi^2)=1.00000000 | R_rms=1.363e-02 | R_rel=1.676e-05
# 2026-09-06 18:57:05,042 - INFO - [L-BFGS] iter 8500/10000 | global_step=28500 | block_iter=100 | block_evals=121 | total_evals=10664 | total=2.055760e-04 | DE=1.840561e-04 | BC=2.151988e-05 | lambda=10.260512025 | int(r*phi^2)=1.00000000 | R_rms=1.357e-02 | R_rel=1.668e-05
# 2026-09-06 18:57:05,258 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:57:05,692 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 18:58:03,177 - INFO - [L-BFGS] iter 8600/10000 | global_step=28600 | block_iter=100 | block_evals=121 | total_evals=10785 | total=2.039366e-04 | DE=1.823707e-04 | BC=2.156585e-05 | lambda=10.260506093 | int(r*phi^2)=1.00000000 | R_rms=1.350e-02 | R_rel=1.661e-05
# 2026-09-06 18:58:57,940 - INFO - [L-BFGS] iter 8700/10000 | global_step=28700 | block_iter=100 | block_evals=123 | total_evals=10908 | total=2.022786e-04 | DE=1.812216e-04 | BC=2.105697e-05 | lambda=10.260454473 | int(r*phi^2)=1.00000000 | R_rms=1.346e-02 | R_rel=1.655e-05
# 2026-09-06 18:59:54,058 - INFO - [L-BFGS] iter 8800/10000 | global_step=28800 | block_iter=100 | block_evals=126 | total_evals=11034 | total=2.005860e-04 | DE=1.794427e-04 | BC=2.114331e-05 | lambda=10.260485447 | int(r*phi^2)=1.00000000 | R_rms=1.340e-02 | R_rel=1.647e-05
# 2026-09-06 19:00:49,671 - INFO - [L-BFGS] iter 8900/10000 | global_step=28900 | block_iter=100 | block_evals=125 | total_evals=11159 | total=1.989216e-04 | DE=1.778325e-04 | BC=2.108907e-05 | lambda=10.260458684 | int(r*phi^2)=1.00000000 | R_rms=1.334e-02 | R_rel=1.640e-05
# 2026-09-06 19:01:44,005 - INFO - [L-BFGS] iter 9000/10000 | global_step=29000 | block_iter=100 | block_evals=122 | total_evals=11281 | total=1.972272e-04 | DE=1.764397e-04 | BC=2.078756e-05 | lambda=10.260466515 | int(r*phi^2)=1.00000000 | R_rms=1.328e-02 | R_rel=1.633e-05
# 2026-09-06 19:01:44,187 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 19:01:44,737 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 19:02:40,152 - INFO - [L-BFGS] iter 9100/10000 | global_step=29100 | block_iter=100 | block_evals=124 | total_evals=11405 | total=1.956742e-04 | DE=1.752258e-04 | BC=2.044845e-05 | lambda=10.260433403 | int(r*phi^2)=1.00000000 | R_rms=1.324e-02 | R_rel=1.628e-05
# 2026-09-06 19:03:34,624 - INFO - [L-BFGS] iter 9200/10000 | global_step=29200 | block_iter=100 | block_evals=123 | total_evals=11528 | total=1.940394e-04 | DE=1.736705e-04 | BC=2.036893e-05 | lambda=10.260400711 | int(r*phi^2)=1.00000000 | R_rms=1.318e-02 | R_rel=1.620e-05
# 2026-09-06 19:04:29,867 - INFO - [L-BFGS] iter 9300/10000 | global_step=29300 | block_iter=100 | block_evals=125 | total_evals=11653 | total=1.923967e-04 | DE=1.721042e-04 | BC=2.029251e-05 | lambda=10.260413926 | int(r*phi^2)=1.00000000 | R_rms=1.312e-02 | R_rel=1.613e-05
# 2026-09-06 19:05:25,233 - INFO - [L-BFGS] iter 9400/10000 | global_step=29400 | block_iter=100 | block_evals=124 | total_evals=11777 | total=1.907827e-04 | DE=1.706381e-04 | BC=2.014461e-05 | lambda=10.260404519 | int(r*phi^2)=1.00000000 | R_rms=1.306e-02 | R_rel=1.606e-05
# 2026-09-06 19:06:21,484 - INFO - [L-BFGS] iter 9500/10000 | global_step=29500 | block_iter=100 | block_evals=127 | total_evals=11904 | total=1.891807e-04 | DE=1.691046e-04 | BC=2.007609e-05 | lambda=10.260368296 | int(r*phi^2)=1.00000000 | R_rms=1.300e-02 | R_rel=1.599e-05
# 2026-09-06 19:06:21,701 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 19:06:22,265 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 19:07:17,897 - INFO - [L-BFGS] iter 9600/10000 | global_step=29600 | block_iter=100 | block_evals=125 | total_evals=12029 | total=1.874759e-04 | DE=1.676639e-04 | BC=1.981201e-05 | lambda=10.260353357 | int(r*phi^2)=1.00000000 | R_rms=1.295e-02 | R_rel=1.592e-05
# 2026-09-06 19:08:12,280 - INFO - [L-BFGS] iter 9700/10000 | global_step=29700 | block_iter=100 | block_evals=123 | total_evals=12152 | total=1.859113e-04 | DE=1.663304e-04 | BC=1.958088e-05 | lambda=10.260329012 | int(r*phi^2)=1.00000000 | R_rms=1.290e-02 | R_rel=1.586e-05
# 2026-09-06 19:09:08,029 - INFO - [L-BFGS] iter 9800/10000 | global_step=29800 | block_iter=100 | block_evals=124 | total_evals=12276 | total=1.842624e-04 | DE=1.647641e-04 | BC=1.949827e-05 | lambda=10.260343447 | int(r*phi^2)=1.00000000 | R_rms=1.284e-02 | R_rel=1.578e-05
# 2026-09-06 19:10:02,378 - INFO - [L-BFGS] iter 9900/10000 | global_step=29900 | block_iter=100 | block_evals=122 | total_evals=12398 | total=1.827710e-04 | DE=1.632940e-04 | BC=1.947707e-05 | lambda=10.260283130 | int(r*phi^2)=1.00000000 | R_rms=1.278e-02 | R_rel=1.571e-05
# 2026-09-06 19:10:56,877 - INFO - [L-BFGS] iter 10000/10000 | global_step=30000 | block_iter=100 | block_evals=123 | total_evals=12521 | total=1.809398e-04 | DE=1.615885e-04 | BC=1.935130e-05 | lambda=10.260319629 | int(r*phi^2)=1.00000000 | R_rms=1.271e-02 | R_rel=1.563e-05
# 2026-09-06 19:10:57,064 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 19:10:57,677 - INFO - Substituting symbol L from STIXNonUnicode
# 2026-09-06 19:10:58,477 - INFO - Training complete.
# 2026-09-06 19:10:58,477 - INFO - Best optimization step: 30000 | phase=L-BFGS | phase_step=10000
# 2026-09-06 19:10:58,477 - INFO - Best total loss: 1.809397627576e-04
# 2026-09-06 19:10:58,492 - INFO - Best lambda: 10.260319629390
# 2026-09-06 19:10:58,494 - INFO - Physical omega: 5.793211116046e+05 rad/s
# 2026-09-06 19:10:58,494 - INFO - Physical frequency: 9.220181854937e+04 Hz
# 2026-09-06 19:10:58,495 - INFO - Best hard clamped-end residuals: Phi(0)=0.000e+00, Phi'(0)=0.000e+00, Phi''(0)=0.000e+00
# 2026-09-06 19:10:58,495 - INFO - Best active free-end residuals: Phi''(1)=1.456e-03, Mbar(1)=1.920e-03, Mbar'(1)=-2.203e-05
# 2026-09-06 19:11:00,011 - INFO - Post-training validation: lambda_ref=10.255824087276 | lambda err=0.043834% | MAC=0.9999999980 | mode rel.L2=4.427681e-05 | frequency err=0.021915%
# ==============================================================================
# FINAL HYBRID PINN RESULTS
# ==============================================================================
# Device                  : cpu
# Best optimization step  : 30000
# Best optimizer phase     : L-BFGS
# Best phase step          : 10000
# Adam epochs completed    : 20000
# L-BFGS iterations        : 10000
# L-BFGS function evals    : 12521
# Best loss                : 1.809397627576e-04
# Best lambda              : 10.260319629390
# Omega [rad/s]            : 5.793211116046e+05
# Frequency [Hz]           : 9.220181854937e+04
# ------------------------------------------------------------------------------
# Independent BVP validation
# Reference lambda         : 10.255824087276
# Lambda error [%]         : 0.043834
# Mass-weighted MAC        : 0.9999999980
# Mode rel. L2             : 4.427681e-05
# Frequency error [%]      : 0.021915
# BVP interior nodes       : 0
# ------------------------------------------------------------------------------
# Relative PDE residual RMS: 1.563064e-05
# Hard clamp residuals     : Phi(0)=0.000e+00, Phi'(0)=0.000e+00, Phi''(0)=0.000e+00
# Free-end residuals       : Phi''(1)=1.456e-03, Mbar(1)=1.920e-03, Mbar'(1)=-2.203e-05
# Normalized mass integral : 1.000000000000
# ==============================================================================
